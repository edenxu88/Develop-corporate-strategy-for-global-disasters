# %% [markdown]
# # Disclosure Keywords Related to Pandemic
#
#
# Reference: https://towardsdatascience.com/keyword-extraction-with-bert-724efca412ea

# %% [markdown]
# ## Dependicies

# %%
#! pip install transformers
#! pip install torchinfo

! pip install  sentence-transformers

! pip install textacy

! pip install spacy

! python -m spacy download en_core_web_sm
# Out:
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.0.0.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 3.6 MB/s eta 0:00:011
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.9.2-py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 6.1 MB/s eta 0:00:01
# Requirement already satisfied: tqdm in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers) (4.50.2)
# Requirement already satisfied: torch>=1.6.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers) (1.8.1)
# Collecting torchvision
#   Downloading torchvision-0.10.0-cp38-cp38-macosx_10_9_x86_64.whl (13.9 MB)
#      |████████████████████████████████| 13.9 MB 17.4 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers) (1.19.2)
# Requirement already satisfied: scikit-learn in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers) (0.24.1)
# Requirement already satisfied: scipy in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: nltk in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from sentence-transformers) (3.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp38-cp38-macosx_10_6_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 42.6 MB/s eta 0:00:01
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.0.15-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 2.8 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (20.4)
# Requirement already satisfied: sacremoses in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.0.44)
# Requirement already satisfied: regex!=2019.12.17 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2020.10.15)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp38-cp38-macosx_10_11_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 34.0 MB/s eta 0:00:01
# Requirement already satisfied: filelock in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.12)
# Requirement already satisfied: pyyaml>=5.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (5.3.1)
# Requirement already satisfied: requests in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2.24.0)
# Requirement already satisfied: typing-extensions in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from torch>=1.6.0->sentence-transformers) (3.7.4.3)
# Requirement already satisfied: pillow>=5.3.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from torchvision->sentence-transformers) (8.0.1)
# Requirement already satisfied: joblib>=0.11 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sentence-transformers) (0.17.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sentence-transformers) (2.1.0)
# Requirement already satisfied: click in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: six in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from packaging->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from packaging->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.0.4)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.0.0-py3-none-any.whl size=126710 sha256=fe4759a08533bbb719ad86eb23c05c4c5684098e12be0699522d17d8af28b799
#   Stored in directory: /Users/zengxu/Library/Caches/pip/wheels/8c/b7/50/451c9a52a337aac5521dbc10544a69e1447d28012feba30742
# Successfully built sentence-transformers
# Installing collected packages: huggingface-hub, tokenizers, transformers, torchvision, sentencepiece, sentence-transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.9.4
#     Uninstalling tokenizers-0.9.4:
#       Successfully uninstalled tokenizers-0.9.4
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.2.2
#     Uninstalling transformers-4.2.2:
#       Successfully uninstalled transformers-4.2.2
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# transformers 4.9.2 requires huggingface-hub==0.0.12, but you'll have huggingface-hub 0.0.15 which is incompatible.
# spacy-transformers 1.0.1 requires transformers<4.3.0,>=3.1.0, but you'll have transformers 4.9.2 which is incompatible.
# huggingface-hub 0.0.15 requires packaging>=20.9, but you'll have packaging 20.4 which is incompatible.
# torchvision 0.10.0 requires torch==1.9.0, but you'll have torch 1.8.1 which is incompatible.
# Successfully installed huggingface-hub-0.0.15 sentence-transformers-2.0.0 sentencepiece-0.1.96 tokenizers-0.10.3 torchvision-0.10.0 transformers-4.9.2
# Requirement already satisfied: textacy in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (0.11.0)
# Requirement already satisfied: requests>=2.10.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from textacy) (2.24.0)
# Requirement already satisfied: tqdm>=4.19.6 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from textacy) (4.50.2)
# Requirement already satisfied: numpy>=1.17.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from textacy) (1.19.2)
# Requirement already satisfied: pyphen>=0.10.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from textacy) (0.11.0)
# Requirement already satisfied: cachetools>=4.0.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from textacy) (4.2.2)
# Requirement already satisfied: joblib>=0.13.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from textacy) (0.17.0)
# Requirement already satisfied: networkx>=2.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from textacy) (2.5)
# Requirement already satisfied: spacy>=3.0.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from textacy) (3.0.5)
# Requirement already satisfied: scikit-learn>=0.19.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from textacy) (0.24.1)
# Requirement already satisfied: cytoolz>=0.10.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from textacy) (0.11.0)
# Requirement already satisfied: jellyfish>=0.8.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from textacy) (0.8.2)
# Requirement already satisfied: scipy>=0.17.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from textacy) (1.5.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.10.0->textacy) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.10.0->textacy) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.10.0->textacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.10.0->textacy) (2.10)
# Requirement already satisfied: decorator>=4.3.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from networkx>=2.0->textacy) (4.4.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy>=3.0.0->textacy) (0.7.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy>=3.0.0->textacy) (3.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy>=3.0.0->textacy) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy>=3.0.0->textacy) (0.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy>=3.0.0->textacy) (2.0.5)
# Requirement already satisfied: setuptools in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy>=3.0.0->textacy) (50.3.1.post20201107)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy>=3.0.0->textacy) (3.0.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy>=3.0.0->textacy) (2.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy>=3.0.0->textacy) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy>=3.0.0->textacy) (20.4)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy>=3.0.0->textacy) (0.3.2)
# Requirement already satisfied: pathy>=0.3.5 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy>=3.0.0->textacy) (0.4.0)
# Requirement already satisfied: jinja2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy>=3.0.0->textacy) (2.11.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy>=3.0.0->textacy) (8.0.2)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy>=3.0.0->textacy) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.19.0->textacy) (2.1.0)
# Requirement already satisfied: toolz>=0.8.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from cytoolz>=0.10.1->textacy) (0.11.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy>=3.0.0->textacy) (2.4.7)
# Requirement already satisfied: six in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy>=3.0.0->textacy) (1.15.0)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy>=3.0.0->textacy) (7.1.2)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy>=3.0.0->textacy) (3.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy>=3.0.0->textacy) (1.1.1)
# Requirement already satisfied: spacy in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (3.0.5)
# Requirement already satisfied: packaging>=20.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (20.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (8.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.7.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.0.1)
# Requirement already satisfied: pathy>=0.3.5 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.4.0)
# Requirement already satisfied: setuptools in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (50.3.1.post20201107)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.24.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: jinja2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.11.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.0.5)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.7.3)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (0.3.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (4.50.2)
# Requirement already satisfied: numpy>=1.15.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (1.19.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (3.0.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy) (2.4.0)
# Requirement already satisfied: six in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy) (3.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: en-core-web-sm==3.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl#egg=en_core_web_sm==3.0.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (3.0.0)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: pathy>=0.3.5 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.4.0)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.3)
# Requirement already satisfied: jinja2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.1)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.50.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.24.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: setuptools in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (50.3.1.post20201107)
# Requirement already satisfied: numpy>=1.15.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.19.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.1.1)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2020.6.20)
# Requirement already satisfied: six in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/zengxu/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.7)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import os
import sys
import time
import copy
import glob
import pickle
import random
import datetime
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, multilabel_confusion_matrix, f1_score, accuracy_score, precision_recall_fscore_support
from sklearn.utils import shuffle

from google.colab import drive

import spacy
from textacy.extract import keyterms

from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a3e721ca38a4> in <module>
#       9 import numpy as np
#      10 import pandas as pd
# ---> 11 import tensorflow as tf
#      12 import matplotlib.pyplot as plt
#      13
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# ## Set up

# %% [markdown]
# Mount drive & Path:

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# set up data path
import sys, os

cur_path = os.path.join('/content/drive/MyDrive/ColabNotebooks')

sys.path.insert(0, cur_path)

os.chdir(cur_path)
print(os.getcwd())
# Out:
# /content/drive/MyDrive/ColabNotebooks

# %% [markdown]
# GPU info

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Thu Aug  5 12:04:29 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import torch
import torchvision

# If there's a GPU available...
if torch.cuda.is_available():    

    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla T4

# %%
#! pip install torchvision
# Out:
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.10.0+cu102)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.19.5)
# Requirement already satisfied: pillow>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (7.1.2)
# Requirement already satisfied: torch==1.9.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (1.9.0+cu102)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.9.0->torchvision) (3.7.4.3)

# %%
#import shutil

#for f in glob.glob("../FastSR_torch_100_25/*.py"):
#  filename = os.path.basename(f)
#  print(filename)
#  shutil.copyfile(f, os.path.join("../FastSR_CNN_30", filename))

# %%
os.getcwd()
# Out:
# '/content/drive/MyDrive/ColabNotebooks'

# %% [markdown]
# # Load Data

# %%
data = pd.read_excel("10K_2020.xlsx",index_col=0).dropna()
data["para_keywords"] = data.para_keywords.apply(lambda x: x.replace("\n",""))
data["para_keywords"] = data.para_keywords.apply(lambda x: x.replace("\xa0",""))
data["para_keywords"] = data.para_keywords.apply(lambda x: x.replace("---------------------------",""))
data.head()
# Out:
#                                                 path  \
# 0  D:\10-K\10-K\20\0000001750\0001104659-20-08531...
# 1  D:\10-K\10-K\20\0000001800\0001104659-20-02390...
# 2  D:\10-K\10-K\20\0000001961\0001264931-20-00005...
# 3  D:\10-K\10-K\20\0000002098\0001564590-20-01085...
# 4  D:\10-K\10-K\20\0000002186\0001654954-20-00224...
#
#                                        para_keywords
# 0  Upon entering the fourth quarter in March, we ...
# 1  2013 to 2015— President, Early Technologies, C...
# 2  After all of our operations were spun off,our ...
# 3  If a pandemic, epidemic or outbreak of an infe...
# 4  InDecember 2019, a strain of the coronavirus s...

# %% [markdown]
# # Load Model and functions

# %%
model = SentenceTransformer('distilbert-base-nli-mean-tokens')

model = SentenceTransformer('sentence-transformers/paraphrase-xlm-r-multilingual-v1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-797960200be0> in <module>
# ----> 1 model = SentenceTransformer('distilbert-base-nli-mean-tokens')
#       2
#       3 model = SentenceTransformer('sentence-transformers/paraphrase-xlm-r-multilingual-v1')
#
# NameError: name 'SentenceTransformer' is not defined

# %%
import numpy as np

def mmr(doc_embedding, word_embeddings, words, top_n, diversity):

    # Extract similarity within words, and between words and the document
    word_doc_similarity = cosine_similarity(word_embeddings, doc_embedding)
    word_similarity = cosine_similarity(word_embeddings)

    # Initialize candidates and already choose best keyword/keyphras
    keywords_idx = [np.argmax(word_doc_similarity)]
    candidates_idx = [i for i in range(len(words)) if i != keywords_idx[0]]

    for _ in range(top_n - 1):
        # Extract similarities within candidates and
        # between candidates and selected keywords/phrases
        candidate_similarities = word_doc_similarity[candidates_idx, :]
        target_similarities = np.max(word_similarity[candidates_idx][:, keywords_idx], axis=1)

        # Calculate MMR
        mmr = (1-diversity) * candidate_similarities - diversity * target_similarities.reshape(-1, 1)
        mmr_idx = candidates_idx[np.argmax(mmr)]

        # Update keywords & candidates
        keywords_idx.append(mmr_idx)
        candidates_idx.remove(mmr_idx)

    return [words[idx] for idx in keywords_idx]

# %%
import numpy as np
import itertools

def max_sum_sim(doc_embedding, word_embeddings, words, top_n, nr_candidates):
    # Calculate distances and extract keywords
    distances = cosine_similarity(doc_embedding, word_embeddings)
    distances_candidates = cosine_similarity(word_embeddings, 
                                            word_embeddings)

    # Get top_n words as candidates based on cosine similarity
    words_idx = list(distances.argsort()[0][-nr_candidates:])
    words_vals = [candidates[index] for index in words_idx]
    distances_candidates = distances_candidates[np.ix_(words_idx, words_idx)]

    # Calculate the combination of words that are the least similar to each other
    min_sim = np.inf
    candidate = None
    for combination in itertools.combinations(range(len(words_idx)), top_n):
        sim = sum([distances_candidates[i][j] for i in combination for j in combination if i != j])
        if sim < min_sim:
            candidate = combination
            min_sim = sim

    return [words_vals[idx] for idx in candidate]

# %% [markdown]
# # Seed list

# %%
seed_financial=["raise additional capital","obtain financing","reduce costs","preserve financial flexibility",
                "sharing contribution","credit reduced","reduce operating expenses","pay salaries","largely maintained case",
                "spend reducing compensation","preserve flexibility","sell shares","focus our portfolio"]

# %%
seed_impact=["exacerbate other risks discussed","absences lower productivity","commercial customer decrease","cargo services reduced","operating loss","disruptions supply","temporarily suspended","absence formal restrictions",
             "economic disruption","impact of change","affect demand airline","damage employee relations","extent pandemic prolong","foreign governments deducted","formal restrictions","employees absence","impacts demand services",
             "negatively impacts demand","economic and market uncertainty","flying overall decline","reduced profitability","tax credits","experienced increase sales","affected travel demand","affect business operating","unable quickly reassemble",
             "continued strength","aftermarket growth trends","disruption fiscal",'delay clinical development',"worker absence","affacted travel demand"]

# %% [markdown]
# # Sentence matching

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(data["para_keywords"].iloc[0])
sents = []
for sent in doc.sents:
  sents.append(sent.text)

# %%
candidate_embeddings = model.encode(sents)
doc_embedding = model.encode(["stoppage","employment subsidies","increase important overall","seek work demand","adjusting business plan",
                "deferred arrangements","support services prolonged","sharing contribution","changes certain assumptions",
                "credit reduced","retain sufficient","reduce demand","decrease commercial","predict the impact","commercial operators evaluate",
                "pay salaries","focus our portfolio","portfolio core services","Services segment give","require considerable","temporarily suspend",
                "increase evaluate sensitivity","assessing impact changes","restrictions employees disruptions","increasing discount rates","defense customers believe",
                "quickly reassemble","believe long","maintenance facilities retain","measure maintain","preserve flexibility liquidity","largely maintained cash",
                "freeze new","additional amounts precautionary","evaluate their structure","retain these contract","adopted policies prohibiting","furloughs reduction force",
                "portion furloughed","employees absence formal","worker absence","draw remaining available","mitigate demand variability","segment commercial customers",
                "relief and stimulus","provide relief stimulus","decrease material","capture customer demand","actions reduce","workforce subsequently retain",
                "maintain good relationships","rates adjusting business","decided sell","actions mitigate impact","exit joint venture","exit underperforming","facilities mitigate demand",
                "quickly reassemble skilled","provide unique skill","skilled personnel return","demand airline cargo","lower productivity","preserve flexibility",
                "ability provide aftermarket","decided sell composites","closure airframe maintenance","require considerable management","spend reducing compensation",
                "sets necessary certain","reduction force closure","demand travel behavior","demand variability customers"])
print(candidate_embeddings.shape)
doc_embedding.shape
# Out:
# (83, 768)
# (72, 768)

# %%
top_n = 20
distances = cosine_similarity(doc_embedding, candidate_embeddings)

# %%
for index in distances.argsort()[0, ::-1][:top_n]:
  print(distances[0, index], sents[index])
# Out:
# 0.3065427 There are no other terms or covenants limiting the availability of this facility.
# 0.2578585 Government Actions to Mitigate COVID-19’s
# 0.24818626 Should the demand for skilled personnel return to pre-COVID-19 levels, and if we are unable to quickly reassemble our skilled workforce and subsequently retain a sufficient number of skilled personnel, or we experience a significant or prolonged work stoppage in such an environment, our ability to secure new work and our results of operations and financial condition could be adversely affected.
# 0.24490565 In the fourth quarter of fiscal 2020, we elected to draw down our Revolving Credit Facility as a precautionary measure in light of economic and market uncertainty presented by COVID-19.
# 0.24490565 In the fourth quarter of fiscal 2020, we elected to draw down our Revolving Credit Facility as a precautionary measure in light of economic and market uncertainty presented by COVID-19.
# 0.2437941 In response to the impact from COVID-19, we implemented significant actions to reduce fixed costs and overhead which included a freeze on new hiring, reducing or eliminating all non-essential spend, reducing compensation and benefits, furloughs, a reduction in force, and closure of an airframe maintenance facility.
# 0.2437941 In response to the impact from COVID-19, we implemented significant actions to reduce fixed costs and overhead which included a freeze on new hiring, reducing or eliminating all non-essential spend, reducing compensation and benefits, furloughs, a reduction in force, and closure of an airframe maintenance facility.
# 0.22345755 Borrowings outstanding under the Revolving Credit Facility at May 31, 2020 were $579.5 million and there were approximately $19.9 million of outstanding letters of credit, which reduced the availability of this facility to $0.6 million.
# 0.21944694 Moreover, a prolonged epidemic or pandemic, or the threat thereof, could result in worker absences, lower productivity, voluntary closure of our offices and facilities, travel restrictions for our employees and other disruptions to our business.
# 0.20806184 Disruptions to our supply chain and business operations, or to our suppliers’ or customers’ supply chains and business operations, could have adverse effects on our ability to provide aftermarket support and services.
# 0.19489037 In response to the impact from COVID-19, we temporarily suspended our matching contributions to the defined contribution plans effective June 1, 2020.
# 0.19162951 During the fourth quarter, we also exited underperforming contracts and assets across our operations and decided to exit our joint venture investment in a Malaysian landing gear wheel and brake facility.
# 0.19162951 During the fourth quarter, we also exited underperforming contracts and assets across our operations and decided to exit our joint venture investment in a Malaysian landing gear wheel and brake facility.
# 0.18886943 Any of these could have a material adverse effect on our business, financial condition or results of operations.
# 0.18821022 These additional borrowings from our Revolving Credit Facility are largely being maintained in Cash and cash equivalents on our Consolidated Balance Sheet which was $404.7 million at May 31, 2020.On March 27, 2020, the Coronavirus Aid, Relief, and Economic Security Act (“CARES Act”) was enacted in the U.S. in response to the COVID-19 pandemic.
# 0.1874969 Reduced numbers of aircraft flying or flight hours negatively impacts the demand for our services, and any prolonged reduction could materially and adversely affect our business, operating results, financial condition, and liquidity.
# 0.18748501 During the fourth quarter of fiscal 2020, the impact from COVID-19 significantly decreased our commercial sales across the majority of our operations.
# 0.18458903 Even in the absence of formal restrictions and prohibitions, contagious illness and fear of contagion has adversely affected travel demand and travel behavior.
# 0.1840011 The payroll tax deferral requires that the deferred payroll taxes be paid over two years, with half of the amount required to be paid by December 31, 2021 and the other half by December 31, 2022.
# 0.17523581 We have elected to account for lease concessions and deferrals resulting directly from COVID-19 as though the enforceable rights and obligations to the deferrals existed in the respective contracts at lease inception and will not account for the concessions as lease modifications.

# %% [markdown]
# # Keywords Matching

# %%
from sklearn.feature_extraction.text import CountVectorizer

n_gram_range = (2,5)
stop_words = "english"

# Extract candidate words/phrases
count = CountVectorizer(ngram_range=n_gram_range).fit([data["para_keywords"].iloc[0]])
candidates = count.get_feature_names()

#drop stopwords
#count = CountVectorizer(ngram_range=n_gram_range, stop_words=stop_words).fit([data["para_keywords"].iloc[0]])
#candidates = count.get_feature_names()

# %%
candidates[0:6]
# Out:
# ['10 year',
#  '10 year senior',
#  '10 year senior unsecured',
#  '10 year senior unsecured promissory',
#  '11 million',
#  '11 million in']

# %%
def extract_keyphrase_ngram(top_n):
    seedphrase = seed_financial
             
    mss_ngram = set()
    mmr_ngram = set()
    similarity_ngram = set()
    candidate_embeddings = model.encode(candidates)
    for i in seedphrase:
        doc_embedding = model.encode([i])
        distances = cosine_similarity(doc_embedding, candidate_embeddings)

    #try different parameters
    max_i = max_sum_sim(doc_embedding, candidate_embeddings, candidates, 5, 15)
    #top_n -> try diff parameters
    mmr_i = mmr(doc_embedding, candidate_embeddings, candidates, top_n=10, diversity=0.5)
    mss_ngram = mss_ngram.union(set(max_i))
    mmr_ngram = mmr_ngram.union(set(mmr_i))

    #for index in distances.argsort()[0, ::-1][:top_n]:
    #  similarity_ngram.add(candidates[index])

  mss_mmr_similarity=mss_ngram.union(mmr_ngram)
  
  return mss_mmr_similarity, distances

# %%
mss_mmr_similarity, distances= extract_keyphrase_ngram(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-5579ab787f07> in <module>
# ----> 1 mss_mmr_similarity, distances= extract_keyphrase_ngram(20)
#
# <ipython-input-13-c50329d71e2e> in extract_keyphrase_ngram(top_n)
#       5   mmr_ngram = set()
#       6   similarity_ngram = set()
# ----> 7   candidate_embeddings = model.encode(candidates)
#       8   for i in seedphrase:
#       9     doc_embedding = model.encode([i])
#
# NameError: name 'model' is not defined

# %%
mss_mmr_similarity
# Out:
# {'10 year senior unsecured',
#  '2020 we decided to',
#  '444 million',
#  'ability to secure new',
#  'account for the concessions as',
#  'actions to preserve flexibility in',
#  'actions to reduce fixed costs',
#  'additional funding',
#  'additional funding remaining',
#  'affected travel demand',
#  'airline cargo services reduced',
#  'also evaluate the sensitivity',
#  'also retained',
#  'and retain',
#  'and retain the',
#  'are largely',
#  'areas the payroll',
#  'be direct',
#  'be used to pay for',
#  'being maintained',
#  'business plan assumptions including',
#  'by financing',
#  'by financing activities continuing operations',
#  'capture the customer',
#  'cares act',
#  'cargo services reduced numbers',
#  'cash used',
#  'certain payroll',
#  'commercial customers decreased',
#  'compensation and',
#  'compensation and benefits furloughs reduction',
#  'continued strength',
#  'contributions to',
#  'contributions to the',
#  'cost of',
#  'costs and',
#  'costs and overhead which',
#  'credit which',
#  'credit which reduced',
#  'customers suppliers',
#  'decided to sell',
#  'decrease in commercial airline activity',
#  'decreased our commercial',
#  'deferred payroll',
#  'demand variability with',
#  'discount rates',
#  'discounted cash',
#  'effective june',
#  'elected to borrow',
#  'elected to borrow these additional',
#  'employee portion',
#  'employee portion of the',
#  'employees to seek work',
#  'enacted similar',
#  'essential spend reducing',
#  'exit our joint venture investment',
#  'expense charged',
#  'facility are largely being maintained',
#  'financial condition and liquidity',
#  'financial condition could be',
#  'financing activities',
#  'financing activities continuing operations',
#  'fixed costs',
#  'flexibility in our',
#  'flexibility in our liquidity',
#  'focus our portfolio',
#  'for lease concessions and deferrals',
#  'foreign subsidiaries',
#  'funding remaining in',
#  'furloughing our employees will',
#  'has historically been',
#  'hiring reducing or',
#  'in mitigating the financial',
#  'in this risk factors',
#  'including profit sharing',
#  'including profit sharing contributions',
#  'income approach',
#  'increase the',
#  'increase we',
#  'investment in',
#  'largely being maintained',
#  'lease concessions',
#  'located at our airframe maintenance',
#  'low interest 10 year senior',
#  'maintained in cash',
#  'matching contributions including profit sharing',
#  'million at',
#  'million of payroll',
#  'mitigating the financial',
#  'net cash provided by financing',
#  'new hiring',
#  'non essential spend reducing compensation',
#  'of capital which is',
#  'of certain of those subsidiaries',
#  'of credit',
#  'of that additional funding remaining',
#  'offerings of value added',
#  'on our results of',
#  'operating loss',
#  'operating loss carrybacks',
#  'or adjusting our business',
#  'our ability',
#  'our matching contributions',
#  'our portfolio',
#  'our stock',
#  'our subsidiaries expect',
#  'pandemic continues to',
#  'pay for the salaries',
#  'payroll tax',
#  'payroll taxes be paid over',
#  'personnel return to pre covid',
#  'portfolio on our',
#  'portfolio on our core',
#  'preserve flexibility',
#  'preserve flexibility in our',
#  'preserve flexibility in our liquidity',
#  'profit sharing',
#  'prohibiting non essential',
#  'prolonged work stoppage',
#  'provide aftermarket support',
#  'provide aftermarket support and services',
#  'recognized employment subsidies of million',
#  'reduce fixed costs and',
#  'reduce fixed costs and overhead',
#  'reduced numbers',
#  'reduced profitability',
#  'reduced the',
#  'reducing compensation',
#  'related expenses on our',
#  'response to the impact',
#  'restrict air',
#  'results financial condition and liquidity',
#  'revolving credit facility are',
#  'risks discussed',
#  'salaries and benefits',
#  'sales across',
#  'see reduced',
#  'sell our composites',
#  'sensitivity scenarios',
#  'services reduced',
#  'sharing contributions',
#  'spend reducing',
#  'spend reducing compensation',
#  'spend reducing compensation and benefits',
#  'stimulus measures to assist',
#  'stock price',
#  'strategy to focus our',
#  'suspended our matching',
#  'taken actions to preserve flexibility',
#  'temporarily suspended',
#  'the deferred payroll',
#  'the defined contribution',
#  'the payroll support',
#  'the salaries and benefits of',
#  'those subsidiaries employees',
#  'to assist',
#  'to assist companies',
#  'to assist companies in mitigating',
#  'to attract and retain the',
#  'to borrow these additional',
#  'to focus our',
#  'to focus our portfolio on',
#  'to million there',
#  'to pay',
#  'to pay for the salaries',
#  'to receive 57 million',
#  'to reduce',
#  'to restrict',
#  'to secure new',
#  'to sell',
#  'venture investment in malaysian',
#  'venture investment in malaysian landing',
#  'we source parts',
#  'which would heighten the',
#  'will increase',
#  'without penalty for',
#  'work stoppage',
#  'would have had fair values'}

# %%
#save to csv file
df = pd.DataFrame(list(mss_mmr_similarity), columns=['mss_mmr_similarity_ngram'])
df.to_csv("809stopwordsmss_mmr_similarity_ngram(2020).csv")

# %%
len(mss_mmr_similarity)
# Out:
# 332

# %%
print(mss_mmr_similarity)
# Out:
# {'demand variability', 'supply chain', 'subsidiary', 'limit', 'source', 'chain and business', 'demand', 'carryback'}

# %% [markdown]
# # Keyterm Matching

# %%
doc = nlp(data["para_keywords"].iloc[0])
results = keyterms.yake(doc, ngrams=(1,2,3,4,5), topn=1000, include_pos = None, window_size = 5)
#keyterms.textrank(doc,  topn=20,  include_pos = None, window_size = 3)
candidates, scores = zip(*results)

candidates= list(candidates)

# %%
len(candidates)
# Out:
# 1000

# %%
seedlist = ['raise additional capital', 'obtain financing', 'reduce costs', 'preserve financial flexibility', 'obtain clinical supplies', 'reduce operating expenses',
            'obtain regulatory approval','exacerbate other risks discussed','obtain sufficient materials','reduce expenses','require additional resources'
            'obtain components', 'develop new', 'obtain supplies', 'attract new customers','perform critical functions', 'remote working arrangements','reduce infection',
            'avoid large gatherings', 'local governments react', 'provide economic relief', 'pay dividends', 'reduce staffing', 'retain key employees', 'reduce operations'
            , 'impose travel restrictions', 'improve profitability', 'find alternate sources', 'maintain social distancing', 'ensure business continuity'
            , 'sell shares', 'reduce production levels', 'identify trends', 'develop effective treatments', 'extend credit', 'ensure uninterrupted service', 'delay clinical development']

# %%
def extract_keyphrase_keyterm(top_n):
  seedphrase = total_seedphrases

  mss_keyterm = set()
  mmr_keyterm = set()
  similarity_keyterm = set()           
  candidate_embeddings = model.encode(list(candidates))
  for i in seedphrase:
    doc_embedding = model.encode([i])
    distances = cosine_similarity(doc_embedding, candidate_embeddings)

    max_i2 = max_sum_sim(doc_embedding, candidate_embeddings, candidates, 20, 20)
    mmr_i2 = mmr(doc_embedding, candidate_embeddings, candidates, top_n=20, diversity=0.5)
    mss_keyterm = mss_keyterm.union(set(max_i2))
    mmr_keyterm = mmr_keyterm.union(set(mmr_i2))

    for index in distances.argsort()[0, ::-1][:top_n]:
      similarity_keyterm.add(candidates[index])
    
  mss_mmr_similarity_keyterm=mss_keyterm.union(mmr_keyterm).union(similarity_keyterm)

    
  return mss_mmr_similarity_keyterm

# %%
mss_mmr_similarity_keyterm = extract_keyphrase_keyterm(20)

# %%
#save to csv file
df1 = pd.DataFrame(list(mss_mmr_similarity_keyterm), columns=['mss_mmr_similarity_keyterm'])
df1.to_csv("2mss_mmr_similarity_keyterm(2020).csv")

# %% [markdown]
# ### Combine the result of n-gram and keyterm matching(drop duplications)

# %%
mss_mmr_similarity_2020 = mss_mmr_similarity_keyterm.union(mss_mmr_similarity)

# %%
len(mss_mmr_similarity_2020)
# Out:
# 2993

# %%
#save to csv file
df1 = pd.DataFrame(list(mss_mmr_similarity_2020), columns=['mss_mmr_similarity_2020'])
df1.to_csv("2mss_mmr_similarity_bothmethod(2020).csv")

mss_mmr_similarity_2020
# Out:
# {'agreement cover',
#  'an income approach',
#  'other areas the payroll',
#  'in demand from commercial airline',
#  'uncertainty in certain',
#  'actions to preserve',
#  'cash and cash equivalent',
#  'States',
#  'government and defense customers',
#  'grant',
#  'defense',
#  'and/or adjust',
#  'follow',
#  'business',
#  'consolidated balance sheet in fiscal',
#  'effective',
#  'essential spend',
#  'formal',
#  'our skilled workforce',
#  'to receive 57',
#  'assessing the impact of',
#  'also exited underperforming contracts',
#  'million will be direct grant',
#  'as forecasts used',
#  'for skilled personnel return',
#  'to pay for',
#  'maintenance facilities we retain these',
#  '10 year senior',
#  'of credit which',
#  'substantially',
#  'evaluate their structure our',
#  'have declared states',
#  'employees will not damage',
#  'reporting units based on',
#  'exit our joint venture investment',
#  'companies in mitigating the financial',
#  'additional funding remain',
#  'or covenants limiting',
#  'financial impact',
#  'the long term we expect',
#  'adopted policies prohibiting non',
#  'subsidies of million from foreign',
#  'into deferral agreements with',
#  'to secure new work',
#  'of credit which reduced',
#  'emergency',
#  'are taking measures to maintain',
#  'supply chain',
#  'subsidies of million',
#  'to seek work elsewhere should',
#  'Facility be largely',
#  'decline in flight hours',
#  'aftermarket growth',
#  'partners and each of their',
#  'relations or cause',
#  'reduce fixed costs',
#  'estimate the fair',
#  'require considerable management judgment in',
#  'flight hours progressively',
#  'to mitigate covid',
#  'more important to our',
#  'extent',
#  'and the other',
#  'reducing compensation and benefits furloughs',
#  'offerings of value',
#  'result in decreased worldwide commercial',
#  'whom are located',
#  'been dependent on',
#  'in wuhan china and',
#  'closure',
#  'decline in demand',
#  'commercial activity',
#  'personnel return to pre covid',
#  'participants would use',
#  'prohibitions contagious illness',
#  'travel demand',
#  'cares act these',
#  'experience a significant',
#  'relief and stimulus measures to',
#  'actions to reduce',
#  'we also retained',
#  'condition could be adversely',
#  'or flight hours',
#  'we decided to sell',
#  'certain assumptions on the',
#  '444 million in fiscal 2020',
#  'operations could have adverse effects',
#  'to secure new work and',
#  'and fear of contagion',
#  'discounted cash flows the',
#  'employees on furlough',
#  'affect our business',
#  'expect to see',
#  'attract and retain the necessary',
#  'of an airframe maintenance facility',
#  'Credit Facility be largely',
#  'supply chains and',
#  'mitigate demand',
#  'will be direct',
#  'concession',
#  'flow valuation',
#  'in certain assumptions on the',
#  'consistent',
#  'Coronavirus Aid',
#  'corresponding decrease in commercial',
#  '2020 the impact',
#  'uncertainty present',
#  'other risks discussed in',
#  'of the impact of',
#  'subsidiaries recognized employment subsidies',
#  'decreased our commercial',
#  'retain these contract',
#  'or prolonged work stoppage in',
#  'to borrow these',
#  'hours the current covid',
#  'reflect',
#  'significant economic disruption',
#  'we believe long term',
#  'the amount required to',
#  'contract workers as they',
#  'and require considerable',
#  'gear wheel',
#  'certain facility',
#  'remaining available borrowings',
#  'exit',
#  'and reduced profitability',
#  'the assumptions we',
#  'credit facility with the',
#  'attract',
#  'work elsewhere should',
#  'restriction',
#  'we source parts and',
#  'covid 19 originated',
#  'there are no other',
#  'year recovery as passenger',
#  'productivity voluntary closure of our',
#  'growth trends are favorable',
#  'services offerings we',
#  'new hiring',
#  'return',
#  'furloughed significant portion',
#  'testing use significant',
#  'the sensitivity of',
#  'portion of certain',
#  'the sales levels',
#  'charged to the consolidated statements',
#  'restrict air travel and many',
#  'employees even in',
#  'response',
#  'skilled workforce as result',
#  '19.9 million',
#  'for these services',
#  'to focus our portfolio',
#  'our composites manufacturing business which',
#  'aftermarket growth trends are favorable',
#  'provide aftermarket',
#  'to see reduced demand',
#  'deferral of the',
#  'sheet which was 404 million',
#  'unit by increasing the',
#  'to focus our',
#  'or modified without penalty for',
#  'fleet types as commercial operators',
#  'would heighten the adverse effects',
#  'created significant economic',
#  'covid 19 and reduced profitability',
#  'overall market capitalization and may',
#  'action to mitigate',
#  'value of our reporting',
#  'significant',
#  'travel by their',
#  'skilled labor allowed us to',
#  'covenants limiting the',
#  'travel demand and travel behavior',
#  'and become more important',
#  'of commercial aircraft',
#  'venture',
#  'cash and cash',
#  'be paid by december 31',
#  'even in the absence',
#  'promissory note net cash',
#  '19 may also',
#  'favorable',
#  'cash provided by financing',
#  'reducing or eliminating',
#  'facility additionally in june',
#  'focus our portfolio on',
#  'number of skilled',
#  'contributions to the',
#  'to see reduced',
#  'malaysian landing gear',
#  'secure new work',
#  'to commercial customers of over',
#  'impairment testing use',
#  'remaining in our cash accounts',
#  'the discounted cash',
#  'defense customers we believe',
#  'that the act of furloughing',
#  'comes from government contracts',
#  'testing use',
#  'in light of economic',
#  'assurance',
#  'step',
#  'that additional funding remaining',
#  'facility at may 31 2020',
#  'to see the impact',
#  'new hiring reducing or eliminating',
#  'the absence of',
#  'us to capture the customer',
#  'be no assurance that',
#  'unable to quickly reassemble',
#  'customers supply chains',
#  'year senior unsecured',
#  'current',
#  '19 pandemic the cares',
#  'commercial sale',
#  'decreased worldwide commercial activity',
#  'ability to secure new',
#  'qualitative',
#  'amounts as precautionary measure in',
#  'revenue',
#  'and subsequently retain sufficient number',
#  'mitigate demand variability',
#  'material effect',
#  'elect to skip',
#  'utilize',
#  'prolong epidemic',
#  'available borrowings under',
#  'and closure of',
#  'take',
#  'COVID-19 significantly',
#  'about the inputs',
#  'spend reducing compensation',
#  'qualitative assessment',
#  'uncertainty',
#  'believe long term commercial aftermarket',
#  'valuation',
#  'through the payroll support',
#  'certain assumptions on',
#  'to capture the customer',
#  'which would heighten the adverse',
#  'material negative',
#  'have had fair values',
#  'corresponding',
#  'and become more',
#  'item',
#  'rate and/or',
#  'taken actions to preserve flexibility',
#  'cargo services reduced',
#  'workers as they provide unique',
#  'assessment',
#  'assume control',
#  'tax credits deferral',
#  'the qualitative assessment',
#  'prolonged work stoppage in such',
#  'sharing contribution',
#  'expect to receive',
#  'the payroll support',
#  'suppliers or customers supply chains',
#  'negatively impacts the demand',
#  'contribution plans effective june',
#  'subsidies of million from',
#  'Consolidated Balance Sheet',
#  'and fear of',
#  'our mro activities',
#  'operators re evaluate their',
#  'amounts as precautionary',
#  'bargaining agreement covering approximately 200',
#  'portfolio',
#  'plan effective June',
#  'secure new',
#  'employment',
#  'to provide relief and stimulus',
#  'covenant limit',
#  'decreased our commercial sales across',
#  'business plan assumptions including slower',
#  'capital',
#  'chain and business operations',
#  'to reduce fixed costs and',
#  'expense charged to',
#  'outstanding letters of credit',
#  'judgment in light',
#  'defense customer',
#  'impact on the company business',
#  'pandemic has decreased',
#  'commercial customers of',
#  'cannot predict the impact',
#  'was enacted in the in',
#  'prohibition',
#  'good relationship',
#  'to draw down our revolving',
#  'operations and financial condition could',
#  'collective',
#  'continue to result',
#  'prohibitions contagious illness and fear',
#  'countries have enacted',
#  'for our services and',
#  'fair value measurements',
#  'freeze on new hiring reducing',
#  'unsecured promissory',
#  'of this facility',
#  'skilled personnel return',
#  'governments which have been',
#  'these services during',
#  'customer demand for these',
#  'reduced demand in our non',
#  'price',
#  'use significant',
#  'certain payroll taxes',
#  'aftermarket support and services moreover',
#  'affected travel demand and',
#  'of the impact',
#  'prohibit',
#  'take measure',
#  'segment given its offerings',
#  'work stoppage in such',
#  'measure in light of',
#  'favorable although there is',
#  'landlords in the fourth',
#  'results of operations',
#  'to the unprecedented impact',
#  'credits deferral of',
#  'portion of the furloughed',
#  'bargaining agreement we',
#  'including by paying the',
#  'being maintained in cash',
#  'aviation industry in response',
#  'travel behavior',
#  'retain sufficient number of skilled',
#  'covenant',
#  'illness',
#  'create significant economic',
#  'covid 19 we temporarily suspended',
#  'and defense customers we believe',
#  'segment to commercial customers',
#  'action to reduce',
#  'would use in measuring',
#  'for all reporting',
#  'or increase the adverse',
#  'reporting units have',
#  'chain and business',
#  'used to estimate the fair',
#  'net cash provide',
#  'risk size and',
#  'productivity voluntary closure of',
#  'not damage employee',
#  'created significant economic disruption during',
#  'on the commercial',
#  'formal restrictions and',
#  'all our sensitivity',
#  'provide unique skill sets which',
#  'demand from commercial',
#  'in this segment',
#  'overall',
#  'trends are favorable although',
#  '19 pandemic and utilized quantitative',
#  'to draw down',
#  'company',
#  'liquidity in addition we source',
#  'year strategy',
#  'implemented significant actions to',
#  'adversely affect the demand',
#  'without penalty for various',
#  'year recovery as',
#  'employment subsidies of million from',
#  'fly and flight',
#  'provide aftermarket support and services',
#  'necessary at certain facilities',
#  'damage employee relations or',
#  'sensitivity',
#  'valuations by assessing the',
#  'the coronavirus pandemic has',
#  'services moreover prolonged epidemic or',
#  'recovery of sales from',
#  'commercial airline activity',
#  'covid-19 level',
#  'financial condition and liquidity and',
#  'and assumed control',
#  'suppliers around the',
#  'demand for airline cargo services',
#  'personnel',
#  'of income for',
#  'disruptions to our supply',
#  'to our overall business',
#  'created significant economic disruption',
#  'to the deferrals',
#  'business travel',
#  'bargaining',
#  'stock price',
#  'subsidiaries expect to',
#  'increase the adverse',
#  'facility as precautionary measure',
#  'aftermarket growth trends are',
#  'carry value',
#  'reporting',
#  'landlords in the fourth quarter',
#  'we furloughed significant portion of',
#  'in sales to commercial',
#  'financial condition could be',
#  'balance sheet other',
#  'costs and overhead',
#  'furloughed significant portion of',
#  'to our suppliers',
#  'foreign governments which have',
#  'assessment approach',
#  'increase and become',
#  'control',
#  'of those subsidiaries employees',
#  'performance as well as forecasts',
#  'retain the necessary skilled labor',
#  'forecasts used in our current',
#  'ImpactOn March',
#  'financial conditions however',
#  'underperforming contracts and assets',
#  'we also evaluate the sensitivity',
#  'the necessary skilled',
#  'employees to seek work',
#  'skip the qualitative assessment',
#  'presented by covid',
#  'receive approximately 48',
#  'see the impact of',
#  'operations was 444',
#  'our employees and other disruptions',
#  'fourth quarter of fiscal',
#  'light of economic',
#  'had material adverse impact',
#  'adopted policies prohibiting non essential',
#  'considerable management judgment in light',
#  'long',
#  'financial condition of any reduction',
#  'hiring reducing or eliminating all',
#  'our actions to mitigate the',
#  'market uncertainty presented',
#  'core services offerings',
#  'size',
#  'government',
#  'of low interest',
#  'employees and other disruptions',
#  'with our customers',
#  'eliminating all non',
#  'portion of our skilled',
#  'through the payroll',
#  'impact the demand',
#  'and deferrals resulting',
#  'benefit of certain',
#  'our core services',
#  'receive',
#  'covid-19 originate in Wuhan',
#  'the deferred payroll',
#  'benefits furloughs reduction',
#  'provided by financing activities',
#  'an airframe maintenance',
#  'implemented significant actions to reduce',
#  'to exit our',
#  'in worker absences lower',
#  'government actions to mitigate',
#  'policies prohibiting non essential business',
#  'market capitalization and may',
#  'related expenses on our',
#  'the long term',
#  'majority of whom',
#  'operations and decided to',
#  'material negative impact',
#  'and assets across',
#  'retained approximately 170 contract workers',
#  'core services offerings we have',
#  'actions to mitigate the',
#  'CARES Act include',
#  'security act cares act',
#  'and decided to exit',
#  'investment',
#  'essential spend reducing compensation',
#  'china and in march',
#  'CARES Act include provision',
#  'goodwill impairment',
#  'financial condition and liquidity',
#  'facility to million there',
#  'progressively increase we also',
#  'seek work elsewhere should',
#  'facility with the majority',
#  'government contract',
#  'volatility',
#  'implemented significant actions',
#  'premium among other items in',
#  'countries including the',
#  'receive approximately 48 million will',
#  'approximately 400 employees',
#  'significant or prolonged work stoppage',
#  'reassemble our skilled workforce',
#  'provide unique skill sets',
#  'all our sensitivity scenarios in',
#  'hours progressively increase',
#  'and closure of an',
#  'average cost of',
#  'our portfolio on our core',
#  'our current business plan',
#  'preserve flexibility in our liquidity',
#  'decided to exit',
#  'outstanding under the',
#  'being maintained in cash and',
#  'additional funding',
#  'wheel',
#  'adversely affect our business operating',
#  'reduced numbers of aircraft',
#  'year primarily',
#  'specific risk',
#  'the demand for airline cargo',
#  'in decreased worldwide commercial activity',
#  'quarter in march',
#  'weight average',
#  'the world health',
#  'landlords in the',
#  'revolving credit facility are largely',
#  'by december 31',
#  'recovery as passenger miles',
#  'limit',
#  'Health Organization characterize',
#  'to commercial customers decreased',
#  'aftermarket support',
#  'current business',
#  'carryback',
#  'impairment testing',
#  'lease modifications as of',
#  'has decreased the amount of',
#  'airline traffic has declined',
#  'the absence of formal restrictions',
#  'have on our customers suppliers',
#  'essential business travel',
#  'limiting the availability of this',
#  'in our liquidity',
#  'our revenue that comes from',
#  'Consolidated Statement',
#  'furloughing our employees',
#  'of any reduction in',
#  'largely being maintained in',
#  'concessions and deferrals',
#  'term commercial aftermarket',
#  'hours and has created significant',
#  'measures to assist',
#  'discuss',
#  'and supporting their employees during',
#  'and industry characteristics',
#  'employment subsidies of million',
#  'new work and',
#  'low interest 10 year senior',
#  'our subsidiaries expect to',
#  'the assumptions we used',
#  'have incorporated decline in',
#  'or cause employees',
#  'are subject to collective bargaining',
#  'experience significant or prolonged',
#  'stimulus measures to assist companies',
#  'support program under',
#  'and market uncertainty presented',
#  'our supply chain',
#  'to provide aftermarket',
#  'policy prohibit',
#  'states of emergency and taken',
#  'to the consolidated',
#  'including slower recovery of',
#  'considerable',
#  'has created significant economic',
#  'work elsewhere should the demand',
#  'worker absences lower productivity',
#  'commercial aviation industry in response',
#  'the salaries and benefits of',
#  'and the duration',
#  'temporarily suspended our matching',
#  'service offering',
#  'we temporarily suspended our',
#  'mitigate the impact',
#  'decreased the amount of commercial',
#  'year strategy to focus',
#  'loss',
#  'to mitigate the impact from',
#  'uncertainty presented by covid',
#  'companies have adopted',
#  '19 approximately 200',
#  'on furlough as of',
#  'other risks discussed',
#  'remaining available borrowings under',
#  'facility as precautionary measure in',
#  'reducing compensation and',
#  'be in the',
#  'countries have enacted similar legislation',
#  'and liquidity in',
#  'unit be base',
#  'additional amount',
#  'and employee portion of',
#  'covid 19 pandemic certain',
#  'demand for airline cargo',
#  'foreign government',
#  'the demand for skilled personnel',
#  'aircraft fly and flight',
#  'profit sharing',
#  'to pay for the',
#  'we retain these',
#  '2020 we furloughed',
#  'the discounted cash flow valuations',
#  'the consolidated statements of',
#  'commercial operator',
#  'begin in April 2020',
#  'plan and require',
#  '404.7 million',
#  'affect our business operating',
#  'are necessary at certain',
#  'Health',
#  'pandemic on the commercial',
#  'year follow',
#  'will not account',
#  'travel demand and travel',
#  'party',
#  'result in worker absences',
#  'hiring',
#  'draw',
#  'act was enacted in',
#  'provided by financing',
#  'the amount of commercial',
#  'employees will not',
#  'become more important',
#  '1,200',
#  'direct',
#  'our joint venture',
#  'have material effect',
#  'productivity',
#  'exacerbate other risks discussed in',
#  'unit using primarily an income',
#  'us to capture the',
#  'hours and has created',
#  'deferral require',
#  'source',
#  'cost',
#  'insurance costs there',
#  'furlough',
#  'prohibiting non essential business travel',
#  'value of each reporting',
#  'expect to continue to see',
#  'given its offerings of value',
#  'airline cargo services reduced',
#  'approximately 170 contract workers',
#  'unable to quickly reassemble our',
#  'agreement',
#  'deferred or modified',
#  'and benefits furloughs reduction',
#  'result directly from covid-19',
#  'increase we also evaluate',
#  'discount cash flow',
#  'foreign governments which have been',
#  'to capture the customer demand',
#  'facilities travel restrictions for our',
#  'the payroll tax deferral',
#  'company business operating',
#  'unit by increasing the discount',
#  'is adjusted for',
#  'at certain facilities',
#  'impacts the demand',
#  'in mitigating the financial',
#  'and taken steps',
#  '2020 we expect to continue',
#  '2020 we furloughed significant',
#  'employee relations or',
#  'of fiscal 2020 the impact',
#  'facility are largely being maintained',
#  'remaining available borrowings under our',
#  'condition of any reduction in',
#  'amount required to',
#  'all three of',
#  'decrease in commercial',
#  'consistent with our',
#  'condition and liquidity in addition',
#  'growth trends are',
#  'workers as of',
#  'product and service',
#  'pandemic has decreased the',
#  'necessary skilled labor allowed us',
#  'payment defer',
#  'rent payments deferred',
#  'focus our portfolio',
#  'assumed control premium',
#  'reduced profitability all of',
#  'employee to seek',
#  'business has historically',
#  'services moreover prolonged',
#  'which reduced the',
#  'and assets across our',
#  'significant unobservable inputs which reflect',
#  'price and assumed control',
#  'generally for minimum',
#  'given its offerings',
#  'discount rates and or adjusting',
#  'our matching contributions',
#  'on our results of',
#  'nine months of the',
#  'employees to seek work elsewhere',
#  'stoppage in such',
#  'travel behavior passenger airline',
#  'employees health insurance costs there',
#  'our business plan assumptions',
#  'of fiscal 2020',
#  'taking measures to maintain good',
#  'Support Program',
#  'the inputs that market',
#  'anticipate that the',
#  'have adopted policies prohibiting',
#  'locate',
#  'define contribution',
#  'of certain payroll',
#  'on furlough as',
#  'covid 19 levels',
#  'relate',
#  'average cost',
#  'own assumptions about',
#  'anticipate',
#  'to restrict air travel',
#  'Government Actions to Mitigate covid-19',
#  'capture the customer demand for',
#  'reducing or eliminating all non',
#  'may be impacted',
#  'freeze on new',
#  'payments deferred under',
#  'support',
#  'assessing the impact',
#  'draw down our remaining available',
#  'non essential business',
#  'focus our portfolio on our',
#  'will be in the form',
#  'insurance cost',
#  'variability with our customers',
#  'impacted by our overall',
#  'financial',
#  'to capture the',
#  'expect to receive approximately 48',
#  'inputs that market',
#  'passenger airline',
#  'work stoppage in',
#  'variability with our customers the',
#  'measure in light',
#  'lease concessions and deferrals',
#  'chains and business operations',
#  'precautionary measure in',
#  'requires that the',
#  'rates and or adjusting',
#  'reduce profitability',
#  'quarter of fiscal 2020',
#  'of payroll taxes',
#  'results of operations and',
#  'decided to sell our',
#  'types as commercial operators re',
#  'offerings of value added services',
#  'our core services offerings we',
#  'be deferred or',
#  'skilled labor allowed',
#  'pandemic could prolong',
#  'require considerable management judgment',
#  'uncertainty present by covid-19',
#  'the concessions as',
#  'relief',
#  'focus',
#  'overall market',
#  'the furloughed employees',
#  'provision',
#  'year strategy to focus our',
#  'behavior passenger airline traffic',
#  'maintenance facilities we',
#  'foreign governments which',
#  'lower productivity voluntary closure of',
#  'and stimulus measures',
#  'supplier',
#  'operator',
#  'condition and liquidity and the',
#  'funding remaining in our',
#  'in the absence',
#  'employee relation',
#  'reduce fixed costs and overhead',
#  'quickly',
#  'arrangement',
#  'funds will be',
#  'core service',
#  'we believe long term commercial',
#  'aviation services segment',
#  'require considerable management',
#  'voluntary closure',
#  'taking measures to maintain',
#  'our customers the',
#  'capture the customer demand',
#  'our matching contributions including',
#  'become more important to',
#  'liquidity and the duration and',
#  'adversely affect travel',
#  'airline cargo service',
#  'spend reducing compensation and',
#  'enforceable right',
#  'Consolidated Balance',
#  'from the related expenses on',
#  'in excess of their carrying',
#  'customers supply chains and business',
#  'wheel and brake',
#  'sales in this',
#  'to restrict air travel and',
#  'economic disruption',
#  'modification',
#  'prolong work',
#  'assist company',
#  'the salaries and',
#  'reduce fix cost',
#  'good relationships with our',
#  'mitigate covid 19 impacton march',
#  'airline',
#  'results of operations in',
#  'receive 57 million',
#  'taxes net operating loss carrybacks',
#  'reporting units is',
#  'decreased our commercial sales',
#  'services reduced numbers of aircraft',
#  '73 million or',
#  'mitigating the financial',
#  'be no assurance',
#  'furloughing our employees will',
#  'countries have enacted similar',
#  'of formal restrictions and prohibitions',
#  'operations are affected by the',
#  'reduce number',
#  'type as commercial',
#  'this facility in',
#  'precautionary measure',
#  'response to the',
#  'at our airframe maintenance facilities',
#  'certain of those subsidiaries',
#  'to exit our joint venture',
#  'outstanding under the revolving credit',
#  'on new hiring',
#  'on our core services',
#  'long term we expect',
#  'elected to borrow these additional',
#  'unprecedented impact',
#  'necessary at certain facilities as',
#  'fixed costs and overhead which',
#  'they provide unique skill',
#  'government actions to mitigate covid',
#  'amount we expect to',
#  'absence',
#  '0.6 million',
#  'fair value the fair',
#  'cause employee',
#  'to assist companies in',
#  'investment in malaysian',
#  'net operating loss',
#  'act cares act was',
#  'consolidated balance sheet other countries',
#  'adversely affect',
#  'base on discount cash',
#  'year senior unsecured promissory',
#  'pay for the salaries and',
#  'an income approach based on',
#  'facility additionally in june 2020',
#  'our services and',
#  'to provide aftermarket support and',
#  'these agreements certain rent',
#  'enacted similar legislation',
#  'has had on',
#  'see reduced demand in our',
#  'as they provide unique skill',
#  'department through the',
#  'carrying values under',
#  'assurance that the act',
#  'COVID-19 significantly decrease',
#  'over the long',
#  'disruptions to our business',
#  'Mitigate covid-19 ’s ImpactOn',
#  'approximately 19 million of outstanding',
#  '5,400 employee',
#  'for the salaries and',
#  '2022',
#  'covid 19 pandemic continues to',
#  'million from foreign',
#  'secure new work and',
#  'through the payroll support program',
#  'of our products and services',
#  'types as commercial operators',
#  'payroll',
#  'material negative impact on',
#  'believe long',
#  'employee be subject',
#  'million government actions',
#  'under these arrangements',
#  'which included freeze on',
#  'trend',
#  'demand',
#  'use significant unobservable inputs which',
#  'our remaining available borrowings',
#  'flight hours we have incorporated',
#  'multi',
#  'operations are affected by',
#  'impact of change',
#  'reduction in the sales levels',
#  'provided by financing activities continuing',
#  'increase the discount',
#  'cares act was enacted',
#  'approach based on discounted cash',
#  'including profit sharing',
#  'salary',
#  'those subsidiaries employees of the',
#  'our ability to provide',
#  'united states have declared',
#  'segment give',
#  'capital which is',
#  'are taking measures to',
#  'and brake facility',
#  'capture the customer',
#  'term',
#  'take action',
#  'income approach base',
#  'similar legislation',
#  'current covid-19 pandemic have decrease',
#  'Consolidated Statement of Income',
#  'skilled personnel or',
#  'minimum of three',
#  'profit sharing contributions was 11',
#  'could result in worker absences',
#  'by increasing the discount rates',
#  'provide unique skill',
#  'flexibility in our liquidity',
#  'facility during the',
#  'we used discount rates based',
#  'operation be affect',
#  'are unable to',
#  'landlord',
#  'ability to secure new work',
#  'employee portion of the furloughed',
#  'have incorporated decline',
#  'used of 47',
#  'june 2020 expense',
#  'terms or covenants',
#  'condition',
#  'commercial aftermarket growth trends are',
#  'services during the',
#  'relief and economic',
#  'temporarily suspended our',
#  'travel',
#  'lease inception',
#  'legislation to provide',
#  'maintenance facility',
#  'subsequently retain',
#  'impacted by the reduced numbers',
#  'employee portion',
#  'operating results financial condition',
#  'outbreak of covid',
#  'units have been impacted by',
#  'relation',
#  '48.5 million',
#  'sell',
#  'measure in light of economic',
#  'affect the demand for',
#  'remaining in our cash',
#  'hiring reducing or',
#  'demand for skilled',
#  'contract worker',
#  'and facilities travel restrictions for',
#  'insurance costs there can',
#  'employ approximately',
#  'our composites manufacturing',
#  'relations or cause employees',
#  'quarter in March',
#  'freeze',
#  'adopt',
#  'good relationships with',
#  'composite manufacture',
#  'increasing the discount rates and',
#  'legislation to provide relief and',
#  'preserve',
#  'judgment',
#  'overall decline in',
#  'services to both',
#  'mitigate',
#  'subsidiaries expect to receive 57',
#  'supply',
#  'subsidy',
#  'outbreak of covid 19 originated',
#  'matching contributions to',
#  'as they provide',
#  'to see reduced demand in',
#  'has historically been dependent on',
#  'Aviation Services',
#  'economic disruption at',
#  'expense charge',
#  'values substantially in',
#  'to maintain good',
#  'no other terms',
#  'act was enacted',
#  'reporting unit base',
#  'consolidated balance sheet other',
#  'that additional funding',
#  'other risks discussed in this',
#  'Revolving Credit Facility be largely',
#  'agreement we also retained',
#  'enforceable rights and',
#  'other business partners',
#  'unique skill sets which are',
#  'or results of operations in',
#  'passenger airline traffic',
#  ...}
