# %%
import stanza
import pandas as pd
from ast import literal_eval

# %%
nlp = stanza.Pipeline(lang="en", processors="tokenize, lemma")
# Out:
# 2021-06-23 21:51:07 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | lemma     | combined |
# ========================
#
# 2021-06-23 21:51:07 INFO: Use device: cpu
# 2021-06-23 21:51:07 INFO: Loading: tokenize
# 2021-06-23 21:51:07 INFO: Loading: lemma
# 2021-06-23 21:51:07 INFO: Done loading processors!

# %%
# drop about 2500 NaN values.
text_2019 = pd.read_excel("10K_2019.xlsx",index_col=0).dropna().reset_index(drop=True)

# %%
text_2019
# Out:
#                                                   path  \
# 0    D:\10-K\10-K\19\0000001800\0001047469-19-00062...
# 1    D:\10-K\10-K\19\0000002186\0001654954-19-00203...
# 2    D:\10-K\10-K\19\0000002969\0000002969-19-00005...
# 3    D:\10-K\10-K\19\0000004281\0000004281-19-00003...
# 4    D:\10-K\10-K\19\0000006281\0000006281-19-00014...
# ..                                                 ...
# 617  D:\10-K\10-K\19\0001742927\0001144204-19-02777...
# 618  D:\10-K\10-K\19\0001749704\0001558370-19-00169...
# 619  D:\10-K\10-K\19\0001750019\0001750019-19-00000...
# 620  D:\10-K\10-K\19\0001758488\0001193125-19-13744...
# 621  D:\10-K\10-K\19\0001772016\0001772016-19-00003...
#
#                                          para_keywords
# 0    2013\nto 2015 — President, Early Technologies,...
# 1    The\noccurrence of one or more natural disaste...
# 2    Our operations could be impacted by catastroph...
# 3    kidnapping of personnel; major public health i...
# 4    •natural disasters or pandemics;\n------------...
# ..                                                 ...
# 617  The occurrence of natural disasters, including...
# 618  “patient census”) and the services those patie...
# 619  Our operations, and those of our CROs, CMOs an...
# 620  Other unscheduled withdrawals of ships from se...
# 621  Our ability to make, move and sell products in...
#
# [622 rows x 2 columns]

# %%
at_least_num_words = 10
#tokenize paragraph to sentences
def sentences_tokenize(paragraph,nlp):
    doc = nlp(paragraph)
    return doc.sentences

def preprocess_paragraph(p):
    return p.replace("\n"," ")

# split original text into list of paragraphs
def get_paragraphs_list(ps):
    return [p for p in preprocess_paragraph(ps).split("---------------------------") if p!="\n"]

# tokenize sentence and lemma it
def get_all_sentences(paras):
    sentences = []
    nlp = stanza.Pipeline(lang='en', processors='tokenize, lemma')
    
    for idx, ps in enumerate(paras):
        print(f"\r{round((idx + 1) / paras.shape[0] * 100, 4)}%", end="", flush=True )
        for p in get_paragraphs_list(ps):
            sts = sentences_tokenize(p, nlp)

            for s in sts:
                if len(s.words) > at_least_num_words:
                    sentences.append(s)
            
    return sentences

# %%
sentences = get_all_sentences(text_2019["para_keywords"])
# Out:
# 2021-06-23 22:30:46 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | lemma     | combined |
# ========================
#
# 2021-06-23 22:30:46 INFO: Use device: cpu
# 2021-06-23 22:30:46 INFO: Loading: tokenize
# 2021-06-23 22:30:46 INFO: Loading: lemma
# 2021-06-23 22:30:46 INFO: Done loading processors!
# 100.0%2%

# %%
lemma_sentences = []

for sentence in sentences:
    tmp_sentence = []
    for word in sentence.words:
        tmp_sentence.append(word.lemma)
        
    lemma_sentences.append(tmp_sentence)

# %% [markdown]
# #  Train word2vec model

# %%
from gensim.models import Word2Vec
import numpy as np

# %%
model = Word2Vec(lemma_sentences, min_count=1, vector_size=100, window=5)
def transform_sentences_to_vector(sentences, model):
    
    vectors = []
    vector_size = model.vector_size
    
    for s in sentences:
        v = np.zeros(vector_size)
        for w in s:
            v += model.wv[w]
        vectors.append(v / len(s))
    
    return vectors

data = transform_sentences_to_vector(lemma_sentences, model)

# %% [markdown]
# # Kmean

# %%
from nltk.cluster import KMeansClusterer, cosine_distance

def group_sentence_by_kmean(lemma_sentences, data, num_clusters=8, repeats=5):
    
    clusterer = KMeansClusterer(num_clusters, cosine_distance, repeats=repeats)

    # samples are assigned to cluster labels 
    # starting from 0
    clusters = clusterer.cluster(data, assign_clusters=True)
    
    results = {i: [] for i in set(clusters)}
    
    for idx, c in enumerate(clusters):
        results[c].append(idx)
    
    return clusterer, results

clusterer, groups = group_sentence_by_kmean(lemma_sentences, data)

def distance(p1, p2):
    return cosine_distance(p1, p2)

def top_sentences_centroid(centroids, groups, data, lemma_sentences, topn=20):
    top_sentences = []
    
    for cid, idxs in groups.items():
        pair_dists = []
        
        for idx in idxs:
            pair_dists.append(distance(centroids[cid], data[idx]))

        print(f"Cluster {cid}:")
        print("----------------------------")
        
        for i in np.array(pair_dists).argsort()[-topn:]:
            print(" ".join(lemma_sentences[idxs[i]]))
            print("----------------------------")
        print()

# %%
top_sentences_centroid(clusterer.means(), groups, data, lemma_sentences)
# Out:
# Cluster 0:
# ----------------------------
# significant limitation on the company 's ability to manufacture product due to disruption of manufacturing operation or related infrastructure could have a material adverse effect on the company 's sale revenue , cost , result of operation , credit rating , and financial condition .
# ----------------------------
# unfavorable global economic condition could adversely affect we business , financial condition , or result of operation .
# ----------------------------
# the potential effect of this condition could have a material adverse effect on we business , result of operation and financial condition .
# ----------------------------
# the effect of global , regional , and local weather condition , and climate change could also adversely impact we result of operation .
# ----------------------------
# we business could be adversely affect by the effect of a public health epidemic .
# ----------------------------
# such closures may disrupt we business operation and adversely affect we result of operation .
# ----------------------------
# any prolong recurrence of any adverse public health development in China may have a material adverse effect on we business operation .
# ----------------------------
# any of this factor could have a adverse effect on we financial result .
# ----------------------------
# any of this factor could have a adverse effect on we financial result .
# ----------------------------
# changes in international tariff structure could adversely impact we product cost .
# ----------------------------
# we operate result could be negatively affect by any of this risk .
# ----------------------------
# decreased travel spend could reduce the demand for we service and have a negative impact on we business and financial performance .
# ----------------------------
# any such disruption could damage we reputation and cause subscriber attrition .
# ----------------------------
# this , in turn , could have a material adverse effect on we business .
# ----------------------------
# this , in turn , could have a material adverse effect on we business .
# ----------------------------
# in the event of adverse weather condition , calamity or epidemic that may occur in the Philippines , the lack of a fully develop infrastructure could have a material adverse impact on top draw 's business .
# ----------------------------
# a labor strike or other transportation disruption affect this port could significantly disrupt we business .
# ----------------------------
# this situation be outside the company 's control and could have a significant adverse impact on the result of operation .
# ----------------------------
# the occurrence of any of this event could have a material adverse effect on we operate result .
# ----------------------------
# decreased travel spend could reduce the demand for tripadvisor 's service and have a negative impact on its business and financial performance .
# ----------------------------
#
# Cluster 1:
# ----------------------------
# any similar natural or manmade disaster that affect a key supplier or customer could lead to a similar disruption in we business .
# ----------------------------
# fluctuating public or scientific interest in the potential for influenza pandemic or other application for we vaccine or other product candidate ; we announcement of significant acquisitions , strategic collaboration , joint venture or capital commitment ;
# ----------------------------
# we operation be locate in Solana Beach , California near major earthquake faults and fire zone .
# ----------------------------
# the extent and severity of this natural disaster determine they effect on the Indian economy .
# ----------------------------
# in addition , concern about terrorism , the effect of a terrorist attack , political turmoil or a outbreak of epidemic disease could have a negative effect on we operation .
# ----------------------------
# some climatic model indicate that global warming may result in rise sea level , increase intensity of weather , and increase frequency of extreme precipitation and flooding .
# ----------------------------
# epidemics , geo-political event , Internet and power outages or natural disaster could adversely affect we business , financial condition , operate result and cash flow .
# ----------------------------
# mattel have experience shortages in the past , include shortages of raw material and component .
# ----------------------------
# a earthquake or other natural disaster or power shortages or outages could disrupt we operation or impair critical system .
# ----------------------------
# we operation could also be disrupt if we supplier , customer or business partner be affect by such natural disaster or health epidemics .
# ----------------------------
# a outbreak of a contagious disease could also negatively affect hospital admission rate .
# ----------------------------
# Natural disaster and other catastrophic event could negatively affect we business .
# ----------------------------
# Natural disaster or other global or regional catastrophic event could disrupt we operation and adversely affect result .
# ----------------------------
# litigation involve allege patent infringement ; epidemic or widespread product failure , or unanticipated safety issue , in one or more of we product ;
# ----------------------------
# litigation involve allege patent infringement ; epidemic or widespread product failure , or unanticipated safety issue , in one or more of we product ;
# ----------------------------
# we corporate headquarters be locate in California near major earthquake faults and fire zone .
# ----------------------------
# we corporate headquarters be in California near major earthquake faults and fire zone .
# ----------------------------
# we corporate headquarters be in Northern California near major earthquake faults and fire zone .
# ----------------------------
# we corporate headquarters be locate in San Diego , California near major earthquake faults and fire zone .
# ----------------------------
# a earthquake or other natural disaster or power shortages or outages could disrupt operation or impair critical system .
# ----------------------------
#
# Cluster 2:
# ----------------------------
# health or similar issue , such as a pandemic or epidemic ; various trade restriction and tax consequence ;
# ----------------------------
# periodic health epidemic concern ; the complexity of manage global operation ; and
# ----------------------------
# af be consider a epidemic cardiovascular disease and a major public health burden .
# ----------------------------
# statement , action or intervention by governmental official related to travel and the result negative public perception of such travel ; condition that negatively shape public perception of travel , include travel - related accident and outbreak of pandemic or contagious disease , such as ebola , avian flu , severe acute respiratory syndrome ( sars ) , h1n1 ( swine flu ) and the zika virus ;
# ----------------------------
# war , political condition or civil unrest , terrorist activity or threat and heighten travel security measure instituted in response to this event ; outbreak of pandemic or contagious disease , such as norovirus , avian flu , severe acute respiratory syndrome ( sars ) , h1n1 ( swine flu ) , ebola , and zika virus ;
# ----------------------------
# political , military , terrorist or major pandemic event ; local labor and social issue ;
# ----------------------------
# change in environmental , health and safety law ; outbreak of disease or epidemics ;
# ----------------------------
# change in environmental , health and safety law ; outbreak of disease or epidemics ;
# ----------------------------
# outbreak of pandemic or contagious disease , such as norovirus , avian flu , severe acute respiratory syndrome ( sars ) , h1n1 ( swine flu ) , ebola , and zika virus ; natural or man-made disaster , such as earthquake , tsunamis , tornadoes , hurricane , typhoons , flood , wildfires , oil spill , and nuclear incidents ;
# ----------------------------
# condition that negatively shape public perception of travel , include travel - related accident , outbreak of pandemic or contagious disease , such as ebola , zika , avian flu , severe acute respiratory syndrome ( sars ) , h1n1 ( swine flu ) and Middle East respiratory syndrome ( mers ) , and perceive negative impact of tourism on local culture and the environment ; climate change or availability of natural resource ;
# ----------------------------
# current geopolitical turmoil and the continue threat of domestic or international terrorism ; the potential emergence of a health pandemic or a infectious disease outbreak ;
# ----------------------------
# Health or similar issue , such as a pandemic or epidemic ;
# ----------------------------
# political unrest , include protest and other civil disruption ; unforeseen public health crises , such as pandemic and epidemic disease ;
# ----------------------------
# condition that negatively shape public perception of travel , include travel - related accident and outbreak of pandemic or contagious disease , such as ebola , avian flu , severe acute respiratory syndrome ( sars ) , h1n1 ( swine flu ) and the zika virus ; climate change or availability of natural resource ;
# ----------------------------
# condition that negatively shape public perception of travel , include travel - related accident and outbreak of pandemic or contagious disease , such as ebola , avian flu , severe acute respiratory syndrome ( sars ) , h1n1 ( swine flu ) and the zika virus ; climate change or availability of natural resource ;
# ----------------------------
# unfavorable tax and currency regulation ; military conflict , terrorist activity and health pandemics or similar issue ;
# ----------------------------
# political policy , political or civil unrest , terrorism or epidemics and other similar outbreak ;
# ----------------------------
# Health or similar issue , such as a pandemic or epidemic
# ----------------------------
# the potential emergence of a health pandemic or a infectious disease outbreak ; the impact of the tax Act and any additional new or propose tax legislation ;
# ----------------------------
# influenza : a worldwide public health problem , include the potential for pandemic disease .
# ----------------------------
#
# Cluster 3:
# ----------------------------
# we have credit exposure to a number of commercial airline , some of which have encounter financial difficulty .
# ----------------------------
# a pandemic , epidemic or outbreak of a contagious disease in the market in which we operate or that otherwise impact we facility could adversely impact we business .
# ----------------------------
# such event could directly impact we physical facility or that of we supplier or customer .
# ----------------------------
# Energy cost , especially fuel cost , also be significant expense in the production and delivery of we product .
# ----------------------------
# losses arise from such event may or may not be fully cover by we various insurance policy or may be subject to deductibles or exceed coverage limit .
# ----------------------------
# any such disruption could damage we reputation and cause customer attrition .
# ----------------------------
# for example , we operation in California be subject to risk related to earthquake .
# ----------------------------
# we may encounter disruptions involve power , communication , transportation or other utility , or essential service depended upon by we or by third party with whom we conduct business .
# ----------------------------
# we do not maintain earthquake insurance and could be materially and adversely affect in the event of a major earthquake .
# ----------------------------
# such event may or may not be fully cover by we various insurance policy or may be subject to deductibles .
# ----------------------------
# fires or other catastrophic event at we principal facility could cripple we business .
# ----------------------------
# we current operation be locate in facility situate in Seattle .
# ----------------------------
# existing insurance coverage may not provide protection for all cost that may arise from such event .
# ----------------------------
# any of this disruptions could affect we internal operation or we ability to deliver product and service to we customer .
# ----------------------------
# undetected quality problem may prompt unexpected product return and adversely affect warranty cost .
# ----------------------------
# a disruption in we ability to provide security monitoring service and otherwise serve we customer could have a material adverse effect on we business .
# ----------------------------
# existing insurance coverage may not provide protection for all of the cost that may arise from such event .
# ----------------------------
# as the Animal Health segment of the company 's business become more significant , the impact of any such event on future result of operation would also become more significant .
# ----------------------------
# Market condition have a significant impact on demand for we commercial aircraft and related service .
# ----------------------------
# Disaster occur at we manufacturing facility could impact we reputation and we customer 's perception of we brands .
# ----------------------------
#
# Cluster 4:
# ----------------------------
# as a result of the substantial reduction in airline traffic result from this event , the airline industry incur large loss and financial difficulty .
# ----------------------------
# development concern any research and development , clinical trials , manufacturing , and marketing effort or collaboration ; fluctuating public or scientific interest in the potential for influenza pandemic or other application for we vaccine or other product candidate ;
# ----------------------------
# Mr. gandolfo have have direct responsibility over capital raise , include five public offering , financial management , merger and acquisition transaction and SEC report throughout he professional career .
# ----------------------------
# if a outbreak of epidemic disease be to occur , numerous response , include travel restriction , might be necessary to combat the spread of the disease .
# ----------------------------
# this risk include fluctuations in currency exchange rate , economic instability and disruptions , restriction on the transfer of fund and the imposition of trade restriction or duty and tariffs .
# ----------------------------
# we have not adopt any write preventive measure or contingency plan to combat any future epidemic outbreak .
# ----------------------------
# as nash progress , scarring , or fibrosis , begin to accumulate in the liver .
# ----------------------------
# outbreak of pandemic disease or fear of such outbreak ; fluctuations in currency exchange rate associate with non - U.S. operation ( include as a result of Brexit ) , hard currency shortages and control on currency exchange that affect demand for we service and we profitability ;
# ----------------------------
# for example , regulation to implement the export Control Reform Act of 2018 could have a adverse effect on we business plan .
# ----------------------------
# we corporate headquarters be locate in Vancouver , British Columbia , which be near a major earthquake fault .
# ----------------------------
# measures to control the disease include , amongst other , marketing only swine test and certified negative for the virus , depopulating infect herds , biosecurity regimens , restricting the movement of pig out of infect zone or region and export ban of live pig .
# ----------------------------
# we principal raw-material need include soybean oil , various sweeteners , egg , dairy - related product , flour , water and various film , plastic and paper packaging material .
# ----------------------------
# the company have in the past experience cyber attack and breach of its computer information system , although none of this have have a material adverse effect on the company 's operation .
# ----------------------------
# BD and medtronic have control U.S. market share ; great financial resource ; large and more establish sale , marketing , and distribution organization ; and great market influence , include long - term and / or exclusive contract .
# ----------------------------
# in addition , a increase in energy cost and the price of fuel to the airline could result in additional pressure on the operate cost of airline .
# ----------------------------
# Dr. Moore have conduct clinical research on infectious disease include Venezuelan equine encephalitis , tuberculosis , listeriosis , psittacosis , malaria , and HIV / aids .
# ----------------------------
# we corporate headquarters be locate in California near major earthquake faults .
# ----------------------------
# for any give viral disease , there be different strains of viruses that cause the disease .
# ----------------------------
# competing therapy be primarily surgical in nature , such as sleeve gastrectomy and gastric bypass .
# ----------------------------
# as of yet most of this company have not make a significant impact on the overall global market but could be consider as a future source of competition .
# ----------------------------
#
# Cluster 5:
# ----------------------------
# we rely on third - party manufacturer to produce and process we product candidate on a patient - by- patient basis .
# ----------------------------
# we rely on third - party manufacturer to produce and process we product candidate on a patient - by- patient basis .
# ----------------------------
# we rely on third - party manufacturer to produce and process we product candidate on a patient - by- patient basis .
# ----------------------------
# we rely on third party manufacturer to produce and process we product candidate .
# ----------------------------
# some of this third - party manufacturer produce product for we competitors .
# ----------------------------
# we rely on third - party manufacturer to produce and process we product candidate .
# ----------------------------
# we rely on third - party manufacturer to produce and process we product candidate .
# ----------------------------
# we rely on third - party manufacturer to produce and process we product candidate .
# ----------------------------
# we rely on third party manufacturer to produce we product candidate .
# ----------------------------
# we rely on third - party manufacturer to produce we product candidate .
# ----------------------------
# we rely on third - party manufacturer to produce we product candidate .
# ----------------------------
# we rely on third - party manufacturer to produce we product candidate .
# ----------------------------
# we rely on third - party manufacturer to produce we product candidate .
# ----------------------------
# we rely on third - party manufacturer to produce we product candidate .
# ----------------------------
# we rely on third - party manufacturer to produce we product candidate .
# ----------------------------
# we rely on third - party manufacturer to produce we product candidate .
# ----------------------------
# we rely on third - party manufacturer to produce we gimoti .
# ----------------------------
# we rely on third - party manufacturer to produce octreotide capsule .
# ----------------------------
# we rely on third - party manufacturer to produce emricasan .
# ----------------------------
# we rely on third - party manufacturer to produce ganaxolone .
# ----------------------------
#
# Cluster 6:
# ----------------------------
# there be no vaccine or prophylactic treatment for this disease .
# ----------------------------
# this may be one of the reason why many antiviral antibodies fail in the field use .
# ----------------------------
# the company make cash donation of $ 0.8 millionand $ 0.5 millionto the m5m Foundation for the year end
# ----------------------------
# mers appear to have be transmit from a animal reservoir to human but human to human transmission have be confirm .
# ----------------------------
# all of we product be manufacture , assemble , test and generally package by a limited number of third - party original design manufacturer ( '' odm '' ) .
# ----------------------------
# we believe the increase emphasis on manage care in the United State have and will continue to put pressure on the price and usage of subsys ® and syndros ® .
# ----------------------------
# the charge represent the amortization of step - up in fair value of inventory acquire in connection with the covidien acquisition .
# ----------------------------
# the company believe that it be adequately reserve for tax related to this year .
# ----------------------------
# the third quarter of 2018 mark the 27th anniversary of the original USDA approval of this product in 1991 .
# ----------------------------
# we be commit to provide health care professional with alternative to traditional opioid base treatment program with we prescription - strength product which have no side-effects .
# ----------------------------
# to a less extent , the company may from time - to - time offer limited indemnification with respect to its software product .
# ----------------------------
# plaintiffs 's complaint name the company and37other entity as defendant .
# ----------------------------
# Mr. watkins have also recently assume responsibility for the company 's communication .
# ----------------------------
# the annual direct cost of treat diabetes in the United State exceed $ 100 billion .
# ----------------------------
# the annual direct cost of treat diabetes in the United State exceed $ 100 billion .
# ----------------------------
# Act require hhs to report to Congress on exist barrier to access to abuse - deterrent opioid formulations by medicare part C and D beneficiaries .
# ----------------------------
# Act require hhs to report to Congress on exist barrier to access to abuse - deterrent opioid formulations by medicare part C and D beneficiaries .
# ----------------------------
# the fair market value of rsu grant be determine base on the market value of the company 's share on the date of grant for period after the company 's separation from covidien plc ( " covidien " ) in fiscal 2013 .
# ----------------------------
# lps constitute the outer leaflet of the outer membrane of most gram-negative bacteria .
# ----------------------------
# shawn T mccormick have serve on we board since September 2014 .
# ----------------------------
#
# Cluster 7:
# ----------------------------
# the financial and general business condition of the airline , automotive and other transportation - related industry and its effect on travel , include decrease airline capacity and route and increase travel cost ; condition that negatively shape public perception of travel , include travel - related accident , outbreak of pandemic or contagious disease , such as ebola , zika , avian flu , severe acute respiratory syndrome ( sars ) , h1n1 ( swine flu ) and Middle East respiratory syndrome ( mers ) , and perceive negative impact of tourism on local culture and the environment ;
# ----------------------------
# prior to join Zimmer biomet , Mr. tornos serve as worldwide President of the global urology , Medical and critical Care divisions of becton , dickinson and company ( '' BD '' ) ( and previously , C. R. bard , Inc. ( '' bard '' ) ) from June 2017 until October 2018 .
# ----------------------------
# therefore one should think of this treatment not really as a h1n1 treatment , but as a potential pandemic flu treatment .
# ----------------------------
# emerging region , such as Eastern Europe , Latin America , Asia , and Africa , as well as more develop market , such as the United Kingdom , France , Germany , and Australia , provide clinical study opportunity for we .
# ----------------------------
# a outbreak or pandemic stem from h5n1 ( avian flu ) or BSE ( mad cow disease ) or any other animal related disease strains could reduce the availability of poultry or beef that be process for the restaurant , food service , wholesale or retail consumer .
# ----------------------------
# potentially attractive life - cycle expansion opportunity for prv - 300 in the infectious disease space include severe influenza in the hospitalize set ( associate with high seasonal mortality ) , acute and chronic respiratory syncytial virus ( RSV ) pathology and emerge viral disease ( e.g. , pandemic or avian flu ) .
# ----------------------------
# Impact of pandemic illness , food borne illness and disease to various agricultural product ;
# ----------------------------
# in connection with the separation from tyco , the adt Corporation enter into a tax share agreement ( '' 2012 tax sharing agreement '' ) that govern the rights and obligation of the adt Corporation , tyco , and pentair Ltd . ( formerly tyco Flow Control International , Ltd. , '' pentair '' ) for certain pre-separation from tyco tax liability , include tyco 's obligation under a 2007 tax share agreement ( '' 2007 tax sharing agreement '' ) among tyco , covidien ( '' covidien '' ) , now operate as a subsidiary of medtronic , and te connectivity Ltd. ( '' te connectivity '' ) .
# ----------------------------
# Galidesivir be a broad - spectrum antiviral ( '' bsav '' ) research program and be currently be develop under contract with the National Institute of allergy and infectious diseases ( '' niaid / hhs '' ) and the U.S. Department of Health and human service ( '' barda / hhs '' ) .
# ----------------------------
# Air travel decline have occur after terrorist attack and heighten security alert , as well as after the high - profile outbreak of disease .
# ----------------------------
# '' patient census '' ) and the service that patient receive .
# ----------------------------
# Act of 1977 , as amend , ( the '' fcpa '' ) , the U.K. bribery Act ( the '' ukba '' ) and similar law , economic sanction law , regulation and regime ( include that administer by the Office of foreign assets Control ( '' ofac '' ) of the U.S. Department of the Treasury ) , and other international law and regulation ;
# ----------------------------
# by formulating a single immunotherapy with some or all of the key sub-types , protection may be achieve against seasonal as well as pandemic strains such as swine flu or pandemic-potential strains , such as avian influenza .
# ----------------------------
# Mr. almeida serve in other executive role with covidien ( formerly tyco healthcare ( tyco ) ) between April 2004 and June 2011 .
# ----------------------------
# for herpes virus infections , shingles , and for viral diseases of the Eye ( adenoviruses , herpesviruses - epidemic kerato-conjunctivitis ( ekc ) , herpes keratitis , viral acute retinal necrosis ( varn ) ) :
# ----------------------------
# the company be subject to risk associate with the outbreak of disease in pork and beef livestock , and poultry flocks , include African swine fever ( asf ) , bovine spongiform encephalopathy ( BSE ) , pneumo-virus , porcine circovirus 2 ( pcv2 ) , porcine reproduction & respiratory syndrome ( prrs ) , Foot -and - mouth Disease ( fmd ) , porcine epidemic diarrhea virus ( pedv ) , and highly pathogenic avian influenza ( hpai ) .
# ----------------------------
# subsidiary guarantors - medtronic luxco , covidien Ltd. , and covidien Group Holding Ltd. ( cifsa subsidiary guarantors )
# ----------------------------
# see '' item 1 - Business - Research and development update - influenza '' for more information .
# ----------------------------
# major domestic competitors include BD and medtronic minimally invasive therapies ( '' medtronic , '' formerly know as covidien ) .
# ----------------------------
# the guidance encourage '' novel approach '' to abuse - deterrent opioid formulations .
# ----------------------------

# %% [markdown]
# # GMM

# %%
from sklearn import mixture

def group_sentence_by_GMM(lemma_sentences, data, num_clusters=8, repeats=5):
    
    gmm = mixture.GaussianMixture(num_clusters,
                              covariance_type="spherical", random_state=42)

    # samples are assigned to cluster labels 
    # starting from 0
    clusters = gmm.fit_predict(data)
    
    results = {i: [] for i in set(clusters)}
    
    for idx, c in enumerate(clusters):
        results[c].append(idx)
    
    return gmm, results



def distance(p1, p2):
    return cosine_distance(p1, p2)

def top_sentences_centroid(centroids, groups, data, lemma_sentences, topn=20):
    top_sentences = []
    
    for cid, idxs in groups.items():
        pair_dists = []
        
        for idx in idxs:
            pair_dists.append(distance(centroids[cid], data[idx]))

        print(f"Cluster {cid}:")
        print("----------------------------")
        
        for i in np.array(pair_dists).argsort()[-topn:]:
            print(" ".join(lemma_sentences[idxs[i]]))
            print("--------------------------------")
        print()

# %%
clusterer, groups = group_sentence_by_GMM(lemma_sentences, data)
top_sentences_centroid(clusterer.means_, groups, data, lemma_sentences)
# Out:
# Cluster 0:
# ----------------------------
# some carrier have also park or retire a portion of they fleets and have reduce workforces and flight .
# --------------------------------
# the guideline do not specifically address the use of buprenorphine for chronic pain or make treatment recommendation about the use of abuse - deterrent opioids .
# --------------------------------
# depend on the final term of Brexit , we could face new regulatory cost and challenge and great volatility in the pound sterling and the Euro .
# --------------------------------
# covidien and the IRS have conclude and reach agreement on its audit of covidien 's U.S. federal income tax return for all tax year through 2012 .
# --------------------------------
# lps or endotoxin translocation be think to be a primary cause of downstream signal in the liver cause inflammation and damage .
# --------------------------------
# the company determine the fair value of its supply agreement liability and above market supply agreement liability with covidien for the year end
# --------------------------------
# we have create a geographic footprint that emphasize locating R&D , engineering and manufacturing capability in close physical proximity to we customer .
# --------------------------------
# the company have recognize approximately $ 114 million in revenue under the hhs barda contract since the inception of the contract .
# --------------------------------
# Beyond we lysin program , we continue we proprietary research to expand we pipeline of complimentary , nontraditional antimicrobials to address unmet medical need .
# --------------------------------
# insurance proceed may not adequately compensate the company for the loss .
# --------------------------------
# the commercial airline industry be impact by the strength of the global economy and the geopolitical event around the world .
# --------------------------------
# we have no long - term contract or arrangement with we third - party manufacturer that guarantee capacity , the continuation of particular payment term or the extension of credit limit .
# --------------------------------
# Act require hhs to report to Congress on exist barrier to access to abuse - deterrent opioid formulations by medicare part C and D beneficiaries .
# --------------------------------
# Act require hhs to report to Congress on exist barrier to access to abuse - deterrent opioid formulations by medicare part C and D beneficiaries .
# --------------------------------
# we rely on foundries to manufacture wafers and on third - party contract manufacturer to assemble , test and manufacture substantially all of we coherent dsp asic , silicon pics , modules and other component .
# --------------------------------
# the most analogous product on the market be dietary supplements .
# --------------------------------
# we corporate strategy be to advance , protect and exploit we differentiated immunotherapy platform .
# --------------------------------
# the cost synergies related to administrative office optimization , manufacturing and supply chain infrastructure , and certain general and administrative savings .
# --------------------------------
# shawn T mccormick have serve on we board since September 2014 .
# --------------------------------
# we Polish operation generate approximately 14 % of our2019 net sale .
# --------------------------------
#
# Cluster 1:
# ----------------------------
# geopolitical and other event , include war , act or threat of terrorism , outbreak of epidemic disease and natural disaster ; cyber risk , include information hack , viruses and malware ; and
# --------------------------------
# long account receivable payment cycle and other collection difficulty ; natural disaster , act of war , terrorism , pandemics or security breach ; and
# --------------------------------
# •telecommunications failure , power outages , pandemics , political unrest , malicious human act and natural disaster .
# --------------------------------
# we financial and operate performance may be adversely affect by epidemics , adverse weather condition , natural disaster and other catastrophes .
# --------------------------------
# rapid change in government , economic and political policy and condition , political or civil unrest or instability , terrorism or epidemics ; fluctuations in foreign currency exchange rate ;
# --------------------------------
# we operation be vulnerable to interruption or loss due to natural disaster , epidemics , terrorist act and other event beyond we control , which could adversely impact we operation .
# --------------------------------
# change in local political , economic , social and labor condition ; natural disaster , act of war , terrorism , pandemics or security breach ;
# --------------------------------
# any of this be subject to failure due to a natural disaster or other disruption .
# --------------------------------
# we business and operate result may be adversely affect by natural disaster , health epidemics or other catastrophic event beyond we control .
# --------------------------------
# financial and civil unrest worldwide ; outbreak of illness , pandemics or other local or global health issue ;
# --------------------------------
# we business could be harmed by the occurrence of natural disaster or pandemic disease .
# --------------------------------
# political , military , terrorist or major pandemic event ; local labor and social issue ;
# --------------------------------
# political policy , political or civil unrest , terrorism or epidemics and other similar outbreak ;
# --------------------------------
# outbreak of pandemic or contagious disease , such as norovirus , avian flu , severe acute respiratory syndrome ( sars ) , h1n1 ( swine flu ) , ebola , and zika virus ; natural or man-made disaster , such as earthquake , tsunamis , tornadoes , hurricane , typhoons , flood , wildfires , oil spill , and nuclear incidents ;
# --------------------------------
# change in environmental , health and safety law ; outbreak of disease or epidemics ;
# --------------------------------
# change in environmental , health and safety law ; outbreak of disease or epidemics ;
# --------------------------------
# Health or similar issue , such as a pandemic or epidemic ;
# --------------------------------
# political unrest , include protest and other civil disruption ; unforeseen public health crises , such as pandemic and epidemic disease ;
# --------------------------------
# Health or similar issue , such as a pandemic or epidemic
# --------------------------------
# unfavorable tax and currency regulation ; military conflict , terrorist activity and health pandemics or similar issue ;
# --------------------------------
#
# Cluster 2:
# ----------------------------
# Airline be sometimes unable to pass on increase in fuel price to customer by increase fares due to the competitive nature of the airline industry , and this compound the pressure on operate cost .
# --------------------------------
# tripadvisor 's business and financial performance be affect by the health of the global economy generally as well as the travel industry and leisure travel in particular .
# --------------------------------
# we current and future , third - party collaborators , future partner , supplies , cro and investigational site be or will be , locate throughout the United State or internationally and may be locate near major high - risk terrorist target , earthquake faults , flood and fire zone .
# --------------------------------
# the majority of we patient be old individual and other with complex medical challenge , many of whom may be more vulnerable than the general public during a pandemic or other public health catastrophe .
# --------------------------------
# in response to this and other terrorist attack around the world , the biodefense market have grow dramatically .
# --------------------------------
# for instance , as a result of the risk associate with marketing opioids , particularly as a result of the opioid epidemic , many insurance company be limiting or eliminate certain policy coverage of opioids .
# --------------------------------
# for example , in 2018 , the United State imposed tariffs on steel and aluminum as well as on goods import from China and certain other country , which have result in retaliatory tariffs by China and other country .
# --------------------------------
# in addition , a increase in energy cost and the price of fuel to the airline could result in additional pressure on the operate cost of airline .
# --------------------------------
# although no global disease pandemic among human have be link to bird flu or other emerge disease to date , government may be pressured to address this concern , include by executive action such as temporarily close certain business , include meat and animal processing facility , within they jurisdictions suspect of contribute to the spread of such disease or by legislative or other policy action , such as prohibit import of animal , meat and animal by- product from country or region where the disease be detect or suspect .
# --------------------------------
# pain continue to represent major clinical , social and economic challenge .
# --------------------------------
# fluctuating public or scientific interest in the potential for influenza pandemic or other application for we vaccine or other product candidate ; we announcement of significant acquisitions , strategic collaboration , joint venture or capital commitment ;
# --------------------------------
# the company have in the past experience cyber attack and breach of its computer information system , although none of this have have a material adverse effect on the company 's operation .
# --------------------------------
# we corporate headquarters be locate in California near major earthquake faults .
# --------------------------------
# Business and personal discretionary spend may decline during general economic downturns or during period of uncertainty about economic condition .
# --------------------------------
# some climatic model indicate that global warming may result in rise sea level , increase intensity of weather , and increase frequency of extreme precipitation and flooding .
# --------------------------------
# demand for we commercial aircraft be further influence by airline profitability , availability of aircraft financing , world trade policy , government - to - government relation , technological advance , price and other competitive factor , fuel price , terrorism , epidemics and environmental regulation .
# --------------------------------
# if a outbreak of epidemic disease be to occur , numerous response , include travel restriction , might be necessary to combat the spread of the disease .
# --------------------------------
# as of yet most of this company have not make a significant impact on the overall global market but could be consider as a future source of competition .
# --------------------------------
# there be no vaccine or prophylactic treatment for this disease .
# --------------------------------
# for any give viral disease , there be different strains of viruses that cause the disease .
# --------------------------------
#
# Cluster 3:
# ----------------------------
# outbreak of disease or epidemics ; potentially negative consequence from change in or interpretation of tax law ;
# --------------------------------
# health or similar issue such as pandemic or epidemic ; difficulty in staffing and manage international operation ;
# --------------------------------
# a outbreak of a contagious disease could also negatively affect hospital admission rate .
# --------------------------------
# we have a business continuity plan design to ( I ) identify key asset , operation and underlying threat , ( ii ) define and assess relevant threat ( e.g. , natural disaster , pandemics , terrorism , etc. ) on business operation , ( iii ) develop and categorize action plan to minimize the impact of the identify threat and ( iv ) test the adequacy of we action plan .
# --------------------------------
# periodic health epidemic concern ; the complexity of manage global operation ; and
# --------------------------------
# af be consider a epidemic cardiovascular disease and a major public health burden .
# --------------------------------
# the potential emergence of a health pandemic or a infectious disease outbreak ; the impact of the tax Act and any additional new or propose tax legislation ;
# --------------------------------
# war , civil unrest , terrorist activity or threat , and heighten travel security measure instituted in response to this event ; fear of outbreak or outbreak of pandemic or contagious disease ;
# --------------------------------
# difficulty in collect account receivable and long collection period ; health or similar issue , such as a pandemic or epidemic ;
# --------------------------------
# natural disaster , act of war , terrorism , pandemics , or security breach ; compliance with various anti-bribery and anti-corruption law such as the U.S. foreign corrupt practices Act ;
# --------------------------------
# statement , action or intervention by governmental official related to travel and the result negative public perception of such travel ; condition that negatively shape public perception of travel , include travel - related accident and outbreak of pandemic or contagious disease , such as ebola , avian flu , severe acute respiratory syndrome ( sars ) , h1n1 ( swine flu ) and the zika virus ;
# --------------------------------
# '' covered countermeasures '' include security countermeasures and '' qualified pandemic or epidemic product , '' include product intend to diagnose or treat pandemic or epidemic disease , as well as treatment intend to address condition cause by such product .
# --------------------------------
# fear of outbreak or outbreak of pandemic or contagious disease ; climate change and resource scarcity , such as water and energy scarcity ;
# --------------------------------
# condition that negatively shape public perception of travel , include travel - related accident , outbreak of pandemic or contagious disease , such as ebola , zika , avian flu , severe acute respiratory syndrome ( sars ) , h1n1 ( swine flu ) and Middle East respiratory syndrome ( mers ) , and perceive negative impact of tourism on local culture and the environment ; climate change or availability of natural resource ;
# --------------------------------
# health or similar issue , such as a pandemic or epidemic ; various trade restriction and tax consequence ;
# --------------------------------
# current geopolitical turmoil and the continue threat of domestic or international terrorism ; the potential emergence of a health pandemic or a infectious disease outbreak ;
# --------------------------------
# influenza : a worldwide public health problem , include the potential for pandemic disease .
# --------------------------------
# condition that negatively shape public perception of travel , include travel - related accident and outbreak of pandemic or contagious disease , such as ebola , avian flu , severe acute respiratory syndrome ( sars ) , h1n1 ( swine flu ) and the zika virus ; climate change or availability of natural resource ;
# --------------------------------
# condition that negatively shape public perception of travel , include travel - related accident and outbreak of pandemic or contagious disease , such as ebola , avian flu , severe acute respiratory syndrome ( sars ) , h1n1 ( swine flu ) and the zika virus ; climate change or availability of natural resource ;
# --------------------------------
# war , political condition or civil unrest , terrorist activity or threat and heighten travel security measure instituted in response to this event ; outbreak of pandemic or contagious disease , such as norovirus , avian flu , severe acute respiratory syndrome ( sars ) , h1n1 ( swine flu ) , ebola , and zika virus ;
# --------------------------------
#
# Cluster 4:
# ----------------------------
# licensed customer that allow the use of they name include : abbott laboratories and abbott vascular , Inc. ( together , '' abbott '' ) , Boston Scientific Corporation ( '' Boston Scientific '' ) , cook Medical , cordis Corporation ( a subsidiary of cardinal Health , Inc. ) , covidien plc ( a subsidiary of medtronic ) , Edwards lifesciences Corporation , evalve , Inc. ( a subsidiary of abbott ) , ev3 Inc. ( a subsidiary of medtronic ) , medtronic , orbusneich Medical , Inc. , and spectranetics Corporation ( a subsidiary of koninklijke philips n.v. ) .
# --------------------------------
# in addition , stera mistcould assist in mitigating the spread of emerge pandemic viruses , include strains of ebola , mers , mlav , h1n1 , h5n1 , h7n9 and h10n8 .
# --------------------------------
# hurricanes , flooding , and temperature extremes , incidents such as the 2017 Las Vegas shootings or 2013 Boston bombing , or infectious pandemics can affect public concern regard large gathering of people , include travel to large populate venue or location .
# --------------------------------
# strains of influenza virus that be resistant to the approve treatment osteltamivir phosphate ( tamiflu ( R ) ) and zanamavir ( relenza ( R ) ) have appear , and in some case predominate .
# --------------------------------
# prior to join Zimmer biomet , Mr. tornos serve as worldwide President of the global urology , Medical and critical Care divisions of becton , dickinson and company ( '' BD '' ) ( and previously , C. R. bard , Inc. ( '' bard '' ) ) from June 2017 until October 2018 .
# --------------------------------
# potentially attractive life - cycle expansion opportunity for prv - 300 in the infectious disease space include severe influenza in the hospitalize set ( associate with high seasonal mortality ) , acute and chronic respiratory syncytial virus ( RSV ) pathology and emerge viral disease ( e.g. , pandemic or avian flu ) .
# --------------------------------
# in connection with the separation from tyco , the adt Corporation enter into a tax share agreement ( '' 2012 tax sharing agreement '' ) that govern the rights and obligation of the adt Corporation , tyco , and pentair Ltd . ( formerly tyco Flow Control International , Ltd. , '' pentair '' ) for certain pre-separation from tyco tax liability , include tyco 's obligation under a 2007 tax share agreement ( '' 2007 tax sharing agreement '' ) among tyco , covidien ( '' covidien '' ) , now operate as a subsidiary of medtronic , and te connectivity Ltd. ( '' te connectivity '' ) .
# --------------------------------
# '' patient census '' ) and the service that patient receive .
# --------------------------------
# Galidesivir be a broad - spectrum antiviral ( '' bsav '' ) research program and be currently be develop under contract with the National Institute of allergy and infectious diseases ( '' niaid / hhs '' ) and the U.S. Department of Health and human service ( '' barda / hhs '' ) .
# --------------------------------
# more than a decade ago , several research group show that no and rns possess anti-viral activity and affect several viruses include coxsackievirus , or cvb , RSV , influenza , severe acute respiratory syndrome , or sars , coronavirus , rhinovirus , herpes simplex virus , or hsv , Epstein - barr virus , or ebv , and other .
# --------------------------------
# water may be subject to contaminant , include hazardous chemical , or pathogen that cause a number of illness , include cholera , typhoid fever , giardiasis , cryptosporidiosis , amoebiasis and free live amoebic infection .
# --------------------------------
# Act of 1977 , as amend , ( the '' fcpa '' ) , the U.K. bribery Act ( the '' ukba '' ) and similar law , economic sanction law , regulation and regime ( include that administer by the Office of foreign assets Control ( '' ofac '' ) of the U.S. Department of the Treasury ) , and other international law and regulation ;
# --------------------------------
# Mr. almeida serve in other executive role with covidien ( formerly tyco healthcare ( tyco ) ) between April 2004 and June 2011 .
# --------------------------------
# for herpes virus infections , shingles , and for viral diseases of the Eye ( adenoviruses , herpesviruses - epidemic kerato-conjunctivitis ( ekc ) , herpes keratitis , viral acute retinal necrosis ( varn ) ) :
# --------------------------------
# the company be subject to risk associate with the outbreak of disease in pork and beef livestock , and poultry flocks , include African swine fever ( asf ) , bovine spongiform encephalopathy ( BSE ) , pneumo-virus , porcine circovirus 2 ( pcv2 ) , porcine reproduction & respiratory syndrome ( prrs ) , Foot -and - mouth Disease ( fmd ) , porcine epidemic diarrhea virus ( pedv ) , and highly pathogenic avian influenza ( hpai ) .
# --------------------------------
# we purchase and use large quantities of commodities , include cocoa , dairy , wheat , palm and other vegetable oil , sugar and other sweeteners , flavor agent and nut .
# --------------------------------
# see '' item 1 - Business - Research and development update - influenza '' for more information .
# --------------------------------
# subsidiary guarantors - medtronic luxco , covidien Ltd. , and covidien Group Holding Ltd. ( cifsa subsidiary guarantors )
# --------------------------------
# major domestic competitors include BD and medtronic minimally invasive therapies ( '' medtronic , '' formerly know as covidien ) .
# --------------------------------
# the guidance encourage '' novel approach '' to abuse - deterrent opioid formulations .
# --------------------------------
#
# Cluster 5:
# ----------------------------
# the ultimate impact on we , we significant supplier and we general infrastructure of be locate near major earthquake faults and fire zone and be consolidated in certain geographical area be unknown , but we operation and financial condition could suffer in the event of a major earthquake , fire or other natural disaster .
# --------------------------------
# the ultimate impact on we , we significant supplier and we general infrastructure of be locate near major earthquake faults and fire zone and be consolidated in certain geographical area be unknown , but we operation and financial condition could suffer in the event of a major earthquake , fire or other natural disaster .
# --------------------------------
# the ultimate impact on we , we significant supplier and we general infrastructure of be locate near major earthquake faults and fire zone and be consolidated in certain geographical area be unknown , but we operation and financial condition could suffer in the event of a major earthquake , fire or other natural disaster .
# --------------------------------
# if we manufacturing facility or any of we customer 's facility be negatively impact by a disaster , shipments of we product could be delay .
# --------------------------------
# we be potentially vulnerable to catastrophic event that could affect we profitability and we ability to carry out we business plan .
# --------------------------------
# we result of operation be dependent on general political , social and economic condition , and the impact of such condition on we theatre operate cost and on the willingness of consumer to spend money at movie theatre .
# --------------------------------
# we result of operation be dependent on general political , social and economic condition , and the impact of such condition on we theatre operate cost and on the willingness of consumer to spend money at movie theatre .
# --------------------------------
# a major earthquake , fire or other disaster , such as a major flood , seasonal storm , or terrorist attack affect we facility , or that of we third - party manufacturer or supplier , could significantly disrupt we or they operation , and delay or prevent product shipment or installation during the time require to repair , rebuild or replace we third - party manufacturer or supplier 's damage manufacturing facility .
# --------------------------------
# any disruption or delay at we manufacturing or distribution facility or customer service center could impair we ability to meet the demand of we customer , and we customer may cancel order with we or purchase product from we competitors , which could adversely affect we business and operate result .
# --------------------------------
# in the event of adverse weather condition , calamity or epidemic that may occur in the Philippines , the lack of a fully develop infrastructure could have a material adverse impact on top draw 's business .
# --------------------------------
# for example , we operation in California be subject to risk related to earthquake .
# --------------------------------
# any prolong recurrence of any adverse public health development in China may have a material adverse effect on we business operation .
# --------------------------------
# changes in international tariff structure could adversely impact we product cost .
# --------------------------------
# decreased travel spend could reduce the demand for we service and have a negative impact on we business and financial performance .
# --------------------------------
# a disruption in we ability to provide security monitoring service and otherwise serve we customer could have a material adverse effect on we business .
# --------------------------------
# such event may or may not be fully cover by we various insurance policy or may be subject to deductibles .
# --------------------------------
# this situation be outside the company 's control and could have a significant adverse impact on the result of operation .
# --------------------------------
# additional outbreak of epidemic disease , or the fear of such event , could result in travel ban or could have a adverse effect on we financial result .
# --------------------------------
# a natural disaster or a pandemic disease could significantly adversely affect both the demand for the company 's product as well as the supply of the component use to make the company 's product .
# --------------------------------
# any of this disruptions could affect we internal operation or we ability to deliver product and service to we customer .
# --------------------------------
#
# Cluster 6:
# ----------------------------
# in addition , a natural disaster , such as a hurricane or a earthquake , could impact we ability to operate certain of we theatre , which could adversely affect we result of operation .
# --------------------------------
# in addition , a natural disaster , such as a hurricane or a earthquake , could impact we ability to operate certain of we theatre , which could adversely affect we result of operation .
# --------------------------------
# accordingly , certain public health catastrophes could have a material adverse effect on we financial condition and result of operation .
# --------------------------------
# accordingly , certain public health catastrophes could have a material adverse effect on we financial condition and result of operation .
# --------------------------------
# any of this disruptions could affect we internal operation or service provide to customer , and could impact we sale , increase we expense or adversely affect we reputation or we stock price .
# --------------------------------
# any of this event could result in a significant drop in demand for we resort and could have a material adverse effect on we .
# --------------------------------
# the effect of global , regional , and local weather condition , and climate change could also adversely impact we result of operation .
# --------------------------------
# any of this factor could have a adverse effect on we financial result .
# --------------------------------
# any of this factor could have a adverse effect on we financial result .
# --------------------------------
# we operate result could be negatively affect by any of this risk .
# --------------------------------
# if this disruptions prevent we from effectively serve we client , we result of operation could be adversely affect .
# --------------------------------
# if this disruptions prevent we from effectively serve we customer , we result of operation could be adversely affect .
# --------------------------------
# this , in turn , could have a material adverse effect on we business .
# --------------------------------
# this , in turn , could have a material adverse effect on we business .
# --------------------------------
# catastrophic event such as natural disaster , pandemics , war and act of terrorism could disrupt we business or the business of we supplier or customer , and any such disruptions could have a negative impact on we operation , financial result and cash flow .
# --------------------------------
# the occurrence of any of this event could have a material adverse effect on we operate result .
# --------------------------------
# Natural disaster or other global or regional catastrophic event could disrupt we operation and adversely affect result .
# --------------------------------
# we operation could also be disrupt if we supplier , customer or business partner be affect by such natural disaster or health epidemics .
# --------------------------------
# we business operation could be significantly harmed by natural disaster or global epidemics .
# --------------------------------
# Natural disaster and other catastrophic event could negatively affect we business .
# --------------------------------
#
# Cluster 7:
# ----------------------------
# we rely on third party manufacturer to produce and process we product candidate .
# --------------------------------
# we rely on third - party manufacturer to produce and process we product candidate on a patient - by- patient basis .
# --------------------------------
# we rely on third - party manufacturer to produce and process we product candidate on a patient - by- patient basis .
# --------------------------------
# we rely on third - party manufacturer to produce and process we product candidate on a patient - by- patient basis .
# --------------------------------
# we rely on third - party manufacturer to produce and process we product candidate .
# --------------------------------
# we rely on third - party manufacturer to produce and process we product candidate .
# --------------------------------
# we rely on third - party manufacturer to produce and process we product candidate .
# --------------------------------
# some of this third - party manufacturer produce product for we competitors .
# --------------------------------
# we rely on third party manufacturer to produce we product candidate .
# --------------------------------
# we rely on third - party manufacturer to produce we product candidate .
# --------------------------------
# we rely on third - party manufacturer to produce we product candidate .
# --------------------------------
# we rely on third - party manufacturer to produce we product candidate .
# --------------------------------
# we rely on third - party manufacturer to produce we product candidate .
# --------------------------------
# we rely on third - party manufacturer to produce we product candidate .
# --------------------------------
# we rely on third - party manufacturer to produce we product candidate .
# --------------------------------
# we rely on third - party manufacturer to produce we product candidate .
# --------------------------------
# we rely on third - party manufacturer to produce we gimoti .
# --------------------------------
# we rely on third - party manufacturer to produce octreotide capsule .
# --------------------------------
# we rely on third - party manufacturer to produce emricasan .
# --------------------------------
# we rely on third - party manufacturer to produce ganaxolone .
# --------------------------------

# %% [markdown]
# # LDA

# %%
sentences = []
for s in lemma_sentences:
    sentences.append(" ".join(s))

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

def group_sentence_by_lda(sentences, num_clusters=8):
    tf_vectorizer = CountVectorizer(min_df=5, stop_words = "english")
    tf = tf_vectorizer.fit_transform(sentences)
    
    tf_feature_names = tf_vectorizer.get_feature_names()
    
    lda = LatentDirichletAllocation(num_clusters, max_iter=30, verbose=1, evaluate_every=1, n_jobs=1, random_state=0)
    
    doc_distribution = lda.fit_transform(tf)
    clusters = doc_distribution.argsort()[:, -1]
    
    results = {i: [] for i in set(clusters)}
    
    for idx, c in enumerate(clusters):
        results[c].append((idx, doc_distribution[idx][c]))
    

    return results

def print_cluster_topn(results, sentences, cluster_number, topn=20):
    topn_sentences = sorted(results[cluster_number], key=lambda x: -x[1])[:topn]
    print(f"Cluster {cluster_number}:\n-------------")
    for idx, score in topn_sentences:
        print(idx, sentences[idx])
        print("---------------------")

# %%
results = group_sentence_by_lda(sentences)

# %%
print_cluster_topn(results, sentences, 0, 20)
# Out:
# Cluster 0:
# -------------
# 3065 the federal physician payments Sunshine Act , enact under the ppaca , which require certain manufacturer of drug , device , biologics , and medical supplies for which payment be available under medicare , medicaid , or the Children 's Health insurance Program , with specific exception , to make annual report to the centers for medicare & medicaid service , or cms , regard any '' transfer of value '' provide to physician and teach hospital .
# ---------------------
# 3057 Failure to submit timely , accurately , and completely the require information for all payment , transfer of value and ownership or investment interest may result in civil monetary penalty of up to a aggregate of $ 150000 per year and up to a additional aggregate of $ 1 million per year for '' know failure , '' for all payment , transfer of value or ownership or investment interest that be not timely , accurately , and completely report in a annual submission .
# ---------------------
# 3062 Failure to submit require information may result in civil monetary penalty of up to a aggregate of $ 150000 per year and up to a additional aggregate of $ 1 million per year for '' know failure , '' for all payment , transfer of value or ownership or investment interest that be not timely , accurately , and completely report in a annual submission .
# ---------------------
# 3066 Failure to submit require information may result in civil monetary penalty of up to a aggregate of $ 150000 per year and up to a additional aggregate of $ 1 million per year for '' know failure , '' for all payment , transfer of value or ownership or investment interest that be not timely , accurately , and completely report in a annual submission .
# ---------------------
# 4033 on March 15 , 2018 , plaintiff Scott ellington , purport to represent the State of Arkansas , more thansixtycounties and a dozen city , file a complaint in Arkansas state court name Gemini laboratories , LLC andfifty - oneother pharmaceutical company as defendant .
# ---------------------
# 4062 on January 23 , 2019 , Indian Health Council , Inc. , request that the company execute a waiver of service pursuant to fed. R. civ. P. 4 and the mdl court 's case management order , in its case pend in the mdl .
# ---------------------
# 4067 on February 7 , 2019 , Kentucky River District Health Department request that the company execute a waiver of service pursuant to fed. R. civ. P. 4 and the mdl court 's case management order , in its case pend in the mdl .
# ---------------------
# 2710 Mr. mccormick serve as Chief Financial Officer of tornier n.v. , a public medical device company , from September 2012 to October 2015 when tornier merge with Wright Medical Group .
# ---------------------
# 2833 Robert J. palmisanowas appoint we President and Chief executive Officer and a executive director and member of we board of director in October 2015 in connection with the Wright / tornier merger .
# ---------------------
# 2671 the carotid stent market in the United State and Europe be dominate by abbott laboratories , Boston Scientific Corporation , covidien Ltd. ( currently part of medtronic , Inc. ) , and cordis Corporation ( currently part of cardinal Health , Inc. ) .
# ---------------------
# 2231 Mr. palmisano have serve as the Chief executive Officer , President and executive director of Wright Medical Group n.v. since September 2011 .
# ---------------------
# 2120 Act ( the " prepact " ) , provide immunity for manufacturer from all claim under state or federal law for " loss " arise out of the administration or use of a " cover countermeasure . "
# ---------------------
# 3548 however , in the event of a accident or incident at this facility , we cannot assure you the amount of insurance will be sufficient to satisfy any damages and loss or that the insurance cover all risk .
# ---------------------
# 2834 Mr. palmisano have serve as President and Chief executive Officer of Wright Medical Group , Inc. since September 2011 .
# ---------------------
# 1351 Mr. shamir join the company on October 14 , 2014 as President and Chief executive Officer and be elect to we board .
# ---------------------
# 4044 on September 24 , 2018 , the distributor defendant remove the case to the United State District Court for the District of Arizona .
# ---------------------
# 3817 from 1987 through 1994 , he be Chief Financial Officer of Medical resources , Inc. , a then publicly hold manager of diagnostic imaging center throughout the United State .
# ---------------------
# 782 information security risk also exist with respect to the use of portable electronic device , such as laptop and smartphone , which be particularly vulnerable to loss and theft .
# ---------------------
# 1851 information security risk also exist with respect to the use of portable electronic device , such as laptop and smartphone , which be particularly vulnerable to loss and theft .
# ---------------------
# 2845 Mr. cordell serve as President , U.S. extremities of Wright Medical Group , Inc. from September 2014 to October 2015 .
# ---------------------
