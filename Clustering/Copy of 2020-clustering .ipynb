# %% [markdown]
# ## Use stanze to break paragragh into sentence and lemmatize each sentence

# %%
import stanza
import pandas as pd
from ast import literal_eval

# %%
pip install stanza
# Out:
# Collecting stanza
#   Downloading https://files.pythonhosted.org/packages/3b/a0/baecd55c7f1108a4b2459f46dde7aa765e393c735662861fe94ba7bc4ba3/stanza-1.2.2-py3-none-any.whl (337kB)
#      |████████████████████████████████| 337kB 6.5MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from stanza) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza) (3.17.3)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza) (1.9.0+cu102)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf->stanza) (1.15.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.0->stanza) (3.7.4.3)
# Installing collected packages: stanza
# Successfully installed stanza-1.2.2

# %%
nlp = stanza.Pipeline(lang='en', processors='tokenize, lemma')
# Out:
# ---------------------------------------------------------------------------
# ResourcesFileNotFoundError                Traceback (most recent call last)
# <ipython-input-4-dbbcd265e20f> in <module>()
# ----> 1 nlp = stanza.Pipeline(lang='en', processors='tokenize, lemma')
#
# /usr/local/lib/python3.7/dist-packages/stanza/pipeline/core.py in __init__(self, lang, dir, package, processors, logging_level, verbose, use_gpu, model_dir, **kwargs)
#      86         resources_filepath = os.path.join(self.dir, 'resources.json')
#      87         if not os.path.exists(resources_filepath):
# ---> 88             raise ResourcesFileNotFoundError(resources_filepath)
#      89         with open(resources_filepath) as infile:
#      90             resources = json.load(infile)
#
# ResourcesFileNotFoundError: Resources file not found at: /root/stanza_resources/resources.json  Try to download the model again.

# %%
text_2020 = pd.read_excel("10K_2020.xlsx",index_col=0).dropna().reset_index(drop=True)

# %%
text_2020
# Out:
#                                                    path  \
# 0     D:\10-K\10-K\20\0000001750\0001104659-20-08531...
# 1     D:\10-K\10-K\20\0000001800\0001104659-20-02390...
# 2     D:\10-K\10-K\20\0000001961\0001264931-20-00005...
# 3     D:\10-K\10-K\20\0000002098\0001564590-20-01085...
# 4     D:\10-K\10-K\20\0000002186\0001654954-20-00224...
# ...                                                 ...
# 2447  D:\10-K\10-K\20\0001795250\0001795250-20-00001...
# 2448  D:\10-K\10-K\20\0001796129\0001564590-20-04438...
# 2449  D:\10-K\10-K\20\0001803284\0001820271-20-00000...
# 2450  D:\10-K\10-K\20\0001804585\0001607062-20-00030...
# 2451  D:\10-K\10-K\20\0001808898\0001193125-20-25238...
#
#                                           para_keywords
# 0     Upon entering the fourth quarter in March, we ...
# 1     2013 to 2015 — President, Early Technologies, ...
# 2     After all of our operations were spun off,\nou...
# 3     If a pandemic, epidemic or outbreak of an infe...
# 4     In\nDecember 2019, a strain of the coronavirus...
# ...                                                 ...
# 2447  Impact of the COVID-19 Pandemic on Our Busines...
# 2448  Management continues to evaluate the impact of...
# 2449  Our business could be adversely affected by th...
# 2450  Based\non the preliminary results from the Pha...
# 2451  the impact of local, regional, and national an...
#
# [2452 rows x 2 columns]

# %%
at_least_num_words = 10
# tokenize paragraph to sentences
def sentences_tokenize(paragraph, nlp): 
    doc = nlp(paragraph)
    return doc.sentences

def preprocess_paragraph(p):
    return p.replace("\n", " ")

# split original text into list of paragraphs (paragraphs are separated by "-------...")
def get_paragraphs_list(ps):
    return [p for p in preprocess_paragraph(ps).split("---------------------------") if p != "\n"]

# tokenize sentence and lemma it
def get_all_sentences(paras):
    sentences = []
    nlp = stanza.Pipeline(lang='en', processors='tokenize, lemma')
    
    for idx, ps in enumerate(paras):
        print(f"\r{round((idx + 1) / paras.shape[0] * 100, 4)}%", end="", flush=True )
        for p in get_paragraphs_list(ps):
            sts = sentences_tokenize(p, nlp)

            for s in sts:
                if len(s.words) > at_least_num_words:
                    sentences.append(s)
            
    return sentences

# %%
sentences = get_all_sentences(text_2020["para_keywords"])
# Out:
# 2021-06-23 21:55:24 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | lemma     | combined |
# ========================
#
# 2021-06-23 21:55:24 INFO: Use device: cpu
# 2021-06-23 21:55:24 INFO: Loading: tokenize
# 2021-06-23 21:55:24 INFO: Loading: lemma
# 2021-06-23 21:55:24 INFO: Done loading processors!
# 100.0%2%

# %%
lemma_sentences = []

for sentence in sentences:
    tmp_sentence = []
    for word in sentence.words:
        tmp_sentence.append(word.lemma)
        
    lemma_sentences.append(tmp_sentence)

# %% [markdown]
# # Train word2vec model

# %%
from gensim.models import Word2Vec
import numpy as np

# %%
model = Word2Vec(lemma_sentences, min_count=1, vector_size=100, window=5)

# %%
def transform_sentences_to_vector(sentences, model):
    
    vectors = []
    vector_size = model.vector_size
    
    for s in sentences:
        v = np.zeros(vector_size)
        for w in s:
            v += model.wv[w]
        vectors.append(v / len(s))
    
    return vectors

# %%
data = transform_sentences_to_vector(lemma_sentences, model)

# %% [markdown]
# # KMean

# %%
from nltk.cluster import KMeansClusterer, cosine_distance

# %%
def group_sentence_by_kmean(lemma_sentences, data, num_clusters=8, repeats=5):
    
    clusterer = KMeansClusterer(num_clusters, cosine_distance, repeats=repeats)

    # samples are assigned to cluster labels 
    # starting from 0
    clusters = clusterer.cluster(data, assign_clusters=True)
    
    results = {i: [] for i in set(clusters)}
    
    for idx, c in enumerate(clusters):
        results[c].append(idx)
    
    return clusterer, results

# %%
clusterer, groups = group_sentence_by_kmean(lemma_sentences, data)

# %%
def distance(p1, p2):
    return cosine_distance(p1, p2)

def top_sentences_centroid(centroids, groups, data, lemma_sentences, topn=20):
    top_sentences = []
    
    for cid, idxs in groups.items():
        pair_dists = []
        
        for idx in idxs:
            pair_dists.append(distance(centroids[cid], data[idx]))

        print(f"Cluster {cid}:")
        print("----------------------------")
        
        for i in np.array(pair_dists).argsort()[-topn:]:
            print(" ".join(lemma_sentences[idxs[i]]))
            print("--------------------------------")
        print()

# %%
results = top_sentences_centroid(clusterer.means(), groups, data, lemma_sentences)
# Out:
# Cluster 0:
# ----------------------------
# we cyber - security could be compromised if person who be force to work from home do not maintain adequate information security .
# --------------------------------
# some of we product be manufacture at a single manufacturing facility or store at a single storage site .
# --------------------------------
# for example , we install physical barrier between employee in production facility , implement extensive clean and sanitation process for both production and office space , and implement broad work - from-home initiative for office personnel .
# --------------------------------
# most of this facility have be reopen to vary degree .
# --------------------------------
# this situation be change rapidly , and additional impact may arise that we be not aware of currently .
# --------------------------------
# we ability to consistently generate cash flow from operate activity be one of we most significant financial strength .
# --------------------------------
# if demand for we product exceed we capacity , it could adversely affect we financial result and customer relationship .
# --------------------------------
# we have experience significant demand reduction and volatility for we product .
# --------------------------------
# unfavorable economic condition could also adversely affect we supplier , distributors , and retailer , who in turn could experience cash flow problem , more costly or unavailable financing , credit default , and other financial hardships .
# --------------------------------
# we may not be able to provide contract manufacturer with product volume that be high enough to achieve sufficient cost savings .
# --------------------------------
# we dsd customer consist of small independent restaurant , foodservice operator , large institutional buyer , and convenience store chain , hotel , casinos , healthcare facility , and foodservice distributors .
# --------------------------------
# this cost increase may not be fully recoverable or adequately cover by insurance .
# --------------------------------
# we supply chain for non-nutritive sweeteners and certain other ingredient for we product include supplier in China .
# --------------------------------
# we cash balance and cash flow from operation be we primary source of liquidity and be generally sufficient to meet we liquidity need .
# --------------------------------
# we principal use of cash in we operate activity be for purchase and carry inventories and carry seasonal account receivable .
# --------------------------------
# we cash and cash equivalent be hold in a mix of money market fund , bank demand deposit account and foreign bank account .
# --------------------------------
# we also manufacture and assemble product and perform various service at we manufacturing facility .
# --------------------------------
# it be not know for how long they will remain close .
# --------------------------------
# we believe we have sufficient liquidity available from operate cash flow , cash on hand , and availability under we $ 2.0 billionrevolving credit facility .
# --------------------------------
# we primary source of liquidity have be cash flow from operate activity .
# --------------------------------
#
# Cluster 1:
# ----------------------------
# the company 's product compete with other nationally advertise brands and with '' private label '' brands within each category .
# --------------------------------
# this report contain statement that plan for or anticipate the future .
# --------------------------------
# although we believe that the expectation reflect in the forward - look statement be reasonable , we can give no assurance that such expectation will prove to be correct .
# --------------------------------
# any or all of the forward - look statement contain in this form 10 - k and any other public statement make by the company or its management may turn out to be incorrect .
# --------------------------------
# expectation do not include tariff rate change or additional tariffs that continue to be consider , but have not yet be imposed .
# --------------------------------
# illness , travel restriction , absenteeism , or other workforce disruptions could negatively affect we supply chain , manufacturing , distribution , or other business process .
# --------------------------------
# we forward - look statement represent we estimate and expectation at the time that we make they .
# --------------------------------
# Act include , among other item , provision relate to refundable payroll tax credits , deferment of certain tax payment , and modifications to the net interest deduction limitation .
# --------------------------------
# it be not clear at this point whether and to what extent this virus , which can be deadly , will spread further .
# --------------------------------
# for example , in 2017 , the U.S. government enact the tax cut and Jobs Act ( tax legislation ) , which make broad and complex change to the U.S. tax code .
# --------------------------------
# natural disaster , health epidemics and geopolitical instability ; complex tax law and potentially adverse tax consequence , include restriction on repatriating earnings and the threat of '' double taxation ; '' and
# --------------------------------
# whether this will be long last or lead to another round of closures be not know .
# --------------------------------
# this report contain forward - look statement relate to present or future trend or factor that be subject to risk and uncertainties .
# --------------------------------
# such forward - look statement be subject to inherent risk and uncertainties that may cause actual result or event to differ materially from that contemplate by such forward - look statement .
# --------------------------------
# forward - look statement can be identify by the fact that they do not relate strictly to historical or current fact .
# --------------------------------
# at this time , we be unable to predict the duration of this action at this time .
# --------------------------------
# widespread health emergency , such as the novel coronavirus or other pandemics or epidemics ; strike and other labor dispute ;
# --------------------------------
# environmental event ; widespread health emergency , such as the novel coronavirus or other pandemics or epidemics ;
# --------------------------------
# •terrorist activity , natural disaster , pandemics and other catastrophic event ;
# --------------------------------
# local political and economic condition ; natural disaster , health epidemics and geopolitical instability ;
# --------------------------------
#
# Cluster 2:
# ----------------------------
# in addition , we receive additional order on we contract value at $ 4.7 million to support a critical U.S. Air Force and U.S. Army anti-jam modem ( '' a3m '' ) program which be intend to provide the U.S. Air Force and U.S. Army with a secure , wideband , anti-jam satellite communication terminal modem for tactical satellite communication operation .
# --------------------------------
# constellation brand , Inc. fy 2020 form 10 - k limit or forgo they time outside of they home .
# --------------------------------
# we three Florida location be reopen in late May but be restrict to 50 % capacity at any time .
# --------------------------------
# accordingly , we expect we result of operation will be adversely affect for we fiscal year end June 30 , 2021 .
# --------------------------------
# stockholders ' equity as of that date be $ 729599 .
# --------------------------------
# see note 3 to we consolidated financial statement in part ii , item 8 of this report .
# --------------------------------
# see discussion in item 8 , note6 for additional information .
# --------------------------------
# cantel Medical Corp. 2020 annual report on form 10 - k significant estimate and assumption that affect the report unit 's expect future cash flow .
# --------------------------------
# no other impairment be identify at the impairment testing date .
# --------------------------------
# a newly introduce consumer product ( whether improve or newly develop ) usually encounter intense competition require substantial expenditure for advertising , sale promotion and trade merchandising support .
# --------------------------------
# Lower unit margin be due to a more competitive pricing environment and weak product mix in the fumed metal oxides product line and weak product mix in we specialty carbons product line due to low demand in automotive application .
# --------------------------------
# substantially all order be expect to be fill within twelve month .
# --------------------------------
# the postponement of elective surgeries have negatively impact the demand for and sale of we product .
# --------------------------------
# almost all location be currently require to operate at only 50 % capacity .
# --------------------------------
# Russia 's underlying net sale growth be drive by high volume of jdtw support by strong consumer demand .
# --------------------------------
# the pharmaceutical system unit 's revenue in 2020 reflect continue strength in demand for prefillable product .
# --------------------------------
# we international sale be primarily through we direct sale force .
# --------------------------------
# Goodwill and indefinite - live intangible asset be initially record at fair value and not amortized , but be test for impairment at least annually or more frequently if impairment indicators arise .
# --------------------------------
# Goodwill be require to be test for impairment at least annually .
# --------------------------------
# the discount cash flow technique require the use of cash flow forecast .
# --------------------------------
#
# Cluster 3:
# ----------------------------
# result be favorably impact by discrete tax item recognize in the fourth quarter ( $ 0.20 per share ) , which include the subsidiary restructurings discuss above , while other discrete tax item provide a benefit of $ 0.08 per share .
# --------------------------------
# Gross profit in fiscal2020decreased $ 41.0 million , or22.9 % , to $ 138.1 millionfrom $ 179.1 millionin fiscal 2019 .
# --------------------------------
# • diluted eps of $ 8.55 increase 8 % , or $ 0.61 , and adjust diluted eps of $ 8.38 increase 2 % , or $ 0.17 .
# --------------------------------
# Canada 's underlying net sale be flat as favorable price / mix be offset by low volume .
# --------------------------------
# the result reflect high demand and good mix during the first half of fiscal year 2020 .
# --------------------------------
# Capital expenditure be $ 299 million in 2020 , $ 384 million in 2019 and $ 407 million in 2018 .
# --------------------------------
# overall , underlying sale decrease 7 percent in the America ( U.S. down 8 percent ) and 3 percent in Europe , while Asia , Middle East & Africa decrease 11 percent ( China down 11 percent ) .
# --------------------------------
# fiscal 2020 operate profitdecreased $ 35 million ( 35 % ) from the prior year .
# --------------------------------
# substantially all U.S. state with a April 15 individual state income tax filing requirement similarly extend they respective deadlines .
# --------------------------------
# substantially all U.S. state with a April 15 individual state income tax filing requirement similarly extend they respective deadlines .
# --------------------------------
# operate expensesincreased as we peo service zero-margin benefit pass-throughcosts increase to $ 2907.
# --------------------------------
# additionally , non-gaap result exclude estimate discrete income tax expense item associate with U.S. tax legislation .
# --------------------------------
# operate cash flow be expect to be approximately $ 3.1 billion and free cash flow , which excludes target capital spend of $ 600 million , be expect to be approximately $ 2.5 billion .
# --------------------------------
# fiscal 2020 it&s segment net salesdecreased by $ 155 million ( 25 % ) from fiscal 2019 to $ 455 million .
# --------------------------------
# we free cash flow , which we define under '' non-gaap Financial measures '' below , be positive $ 21.8 millionas compare to negative $ 53.7 millionfor the same period a year ago .
# --------------------------------
# we be award a number of important order include : ( I ) contract value at more than $ 2.2 million for ka-band high - power travel wave tube amplifiers ( '' twtas '' ) for trailer - base satellite communication terminals ; ( ii ) a contract value at more than $ 1.5 million for 500w ka-band twtas for a track , telemetry and command application to be deploy globally by a major satellite service provider ; ( iii ) $ 1.3 million in order for advanced satellite modems , wan optimization and redundancy switch to support cellular lte backhaul for a service provider in the Middle East ; and ( iv ) a $ 1.1 million order for satellite ground station equipment from a South East Asia Ministry of Defense for a network upgrade , which could expand to more than 2000 unit .
# --------------------------------
# Cash flow provide by financing activity for fiscal 2020 be primarily attribute to the net fund receive from nine ( 9 ) unsecured promissory note payable under cares Act payroll Protection Program ( '' ppp '' ) total $ 19,927 in order to provide need relief for allowable expense under the cares Act ppp .
# --------------------------------
# the divestiture of two small non- core business subtracted 1 percent ( $ 42 ) and foreign currency translation deduct 1 percent ( $ 30 ) .
# --------------------------------
# we also generate $ 52.8 million of cash flow from operation .
# --------------------------------
# cantel Medical Corp. 2020 annual report on form 10 - k the second quarter of fiscal 2019 .
# --------------------------------
#
# Cluster 4:
# ----------------------------
# any of the foregoing could adversely affect we business , financial condition and result of operation .
# --------------------------------
# any of this event could adversely affect we business , result of operation and financial condition .
# --------------------------------
# Potential volatility in the trading price of the marketable securities hold by the company could impact the company 's opportunity for expansion .
# --------------------------------
# there be no certainty that such measure will be sufficient to mitigate the risk pose by the virus , and we ability to perform critical function could be harmed .
# --------------------------------
# the impact on we unfilled wholesale order position be unknown at this time .
# --------------------------------
# the impact on we unfilled wholesale order position be unknown at this time .
# --------------------------------
# we have not laid off any of we employee or reduce they salaries due to covid - 19.
# --------------------------------
# such disruptions could have a adverse effect on we operate result and financial condition .
# --------------------------------
# as a result , we business , financial condition and result of operation could be materially adversely affect .
# --------------------------------
# the covid - 19 global pandemic may materially and adversely impact we business , financial condition and result of operation .
# --------------------------------
# geopolitical crisis , include terrorism or pandemics , could adversely affect we business .
# --------------------------------
# uncertain economic and financial market condition may also adversely affect the financial condition of the company 's customer , supplier and other business partner .
# --------------------------------
# the coronavirus pandemic and associate containment effort adversely affect we business , result of operation and cash flow during fiscal 2020 .
# --------------------------------
# this could have a material adverse effect on we result of operation , financial condition and cash flow .
# --------------------------------
# any such disruption would likely materially and adversely affect we operate result and financial condition .
# --------------------------------
# a natural disaster could disrupt we operation , or we customer 's or supplier 's operation and could adversely affect we result of operation and financial condition .
# --------------------------------
# unfavorable global or regional economic condition could adversely affect we business and financial result .
# --------------------------------
# this may adversely affect we result of operation , financial position and cash flow .
# --------------------------------
# Act on we condense consolidated statement of operation and we condense consolidated statement of cash flow .
# --------------------------------
# there be a risk this may not always be the case .
# --------------------------------
#
# Cluster 5:
# ----------------------------
# reader of this report should understand that this forward - look statement be not guarantee of performance or result .
# --------------------------------
# we believe this forward - look statement be base upon reasonable assumption .
# --------------------------------
# the follow promissory note be execute by the company and its subsidiaries : gee Group , Inc. , for $ 1992 ( the '' gee Group note '' ) , scribe solution , Inc. for $ 277 ( the '' scribe note '' ) , agile resources , Inc. be for $ 1206 ( the '' agile note '' ) , access data consulting Corporation for $ 1456 ( the '' access note '' ) , paladin consulting , Inc. for $ 1,925 ( the '' paladin note '' ) , sni company , Inc. for $ 10000 ( the '' sni note '' ) , triad personnel service , Inc. for $ 404 ( the '' triad personnel note '' ) , triad logistics , Inc. for $ 78 ( the '' triad logistics note '' ) , and bmch , Inc. for $ 2589 ( the '' bmch note '' ) .
# --------------------------------
# Mr. almeida serve in other executive role with covidien ( formerly tyco healthcare ( tyco ) ) between April 2004 and June 2011 .
# --------------------------------
# when use in this annual report , word such as '' anticipate , '' '' believe , '' '' contemplates , '' '' estimate , '' '' expect , '' '' plan , '' '' project '' and similar expression be intend to identify forward - look statement .
# --------------------------------
# all forward - look statement speak only as of the date of this annual report on form 10 - K.
# --------------------------------
# we caution reader not to place undue reliance on any forward - look statement .
# --------------------------------
# word such as '' could , '' '' will , '' '' may , '' '' expect , '' '' anticipate , '' '' target , '' '' goal , '' '' project , '' '' intend , '' '' plan , '' '' believe , '' '' seek , '' '' estimate , '' '' predicts '' and variations on such word , and similar expression that reflect we current view with respect to future event and operational and financial performance , be intend to identify such forward - look statement .
# --------------------------------
# all statement other than statement of historical fact be statement that could be deem forward - look statement .
# --------------------------------
# you can identify forward - look statement by terminology such as '' may , '' '' should , '' '' expect , '' '' plan , '' '' anticipate , '' '' believe , '' '' estimate , '' '' predicts , '' '' potential , '' '' continue , '' or the negative of this term or other comparable terminology .
# --------------------------------
# all statement other than statement of historical fact be statement that could be forward - look statement .
# --------------------------------
# the global outbreak of the novel strain of coronavirus covid - 19 disease be declare a pandemic by the World Health Organization ( who ) during March 2020 .
# --------------------------------
# see '' liquidity and Capital resources '' below for detail .
# --------------------------------
# forward - look statement may contain word such as '' may , '' '' will , '' '' should , '' '' could , '' '' would , '' '' expect , '' '' plan , '' '' anticipate , '' '' believe , '' '' estimate , '' '' intend , '' '' potential '' and '' continue , '' the negative of this term , or other comparable terminology .
# --------------------------------
# without limiting the foregoing , word or phrase such as '' expect , '' '' anticipate , '' '' goal , '' '' project , '' '' intend , '' '' plan , '' '' believe , '' '' seek , '' '' may , '' '' could , '' '' aspire '' and variations of such word and similar expression generally identify forward - look statement .
# --------------------------------
# the term '' may , '' '' should , '' '' could , '' '' anticipate , '' '' believe , '' '' estimate , '' '' expect , '' '' objective , '' '' plan , '' '' project '' and similar expression be intend to identify forward - look statement .
# --------------------------------
# forward - look statement include all statement that be not historical fact and can be identify by term such as '' anticipate , '' '' believe , '' '' could , '' '' estimate , '' '' expect , '' '' hope , '' '' intend , '' '' may , '' '' plan , '' '' potential , '' '' predicts , '' '' project , '' '' should , '' '' will , '' '' would '' or similar expression .
# --------------------------------
# word such as '' expect , '' '' anticipate , '' '' target , '' '' goal , '' '' project , '' '' intend , '' '' plan , '' '' believe , '' '' seek , '' '' estimate , '' '' continue , '' '' may , '' '' could '' and '' will , '' and variations of such word and similar expression be intend to identify such forward - look statement .
# --------------------------------
# you can identify this forward - look statement through the use of word such as '' may , '' '' will , '' '' can , '' '' anticipate , '' '' assume , '' '' should , '' '' indicate , '' '' would , '' '' believe , '' '' contemplate , '' '' expect , '' '' seek , '' '' estimate , '' '' continue , '' '' plan , '' '' project , '' '' predict , '' '' could , '' '' intend , '' '' target , '' '' potential , '' and other similar word and expression of the future .
# --------------------------------
# some of the forward - look statement can be identify by word like '' anticipate , '' '' believe , '' '' expect , '' '' may , '' '' will , '' '' can , '' '' could , '' '' should , '' '' intend , '' '' project , '' '' predict , '' '' plan , '' '' estimate , '' '' goal , '' '' target , '' '' possible , '' '' potential , '' '' would , '' '' seek , '' and similar reference to future period .
# --------------------------------
#
# Cluster 6:
# ----------------------------
# Fair value be measure use the relief - from-royalty method .
# --------------------------------
# additionally , because of the covid - 19 pandemic during the second half of the company 's fiscal year end
# --------------------------------
# the second half of the fiscal year end July , 31 , 2020 be impact by the coronavirus ( covid - 19 ) pandemic , result in atypical seasonality .
# --------------------------------
# the company have incur operate loss in its last four complete fiscal year , as well as cash use in operate activity in its last two complete fiscal year .
# --------------------------------
# the company have incur operate loss in its last four complete fiscal year , as well as cash use in operate activity in its last two complete fiscal year .
# --------------------------------
# the latter half of the fiscal year be negatively impact by the covid - 19 pandemic as net sale decrease by approximately 75 % during the third quarter of fiscal 2020 .
# --------------------------------
# the impact of the covid - 19 pandemic on dsd revenue be during the second half of we fiscal year end
# --------------------------------
# although we get off to a good start , during we second half of fiscal 2020 , the outbreak of the coronavirus disease 2019 ( '' covid - 19 '' ) be declare a pandemic by the World Health Organization and a national emergency by the U.S. government .
# --------------------------------
# the outbreak be subsequently declare a pandemic by the World Health Organization in March 2020 .
# --------------------------------
# overall demand for we product have decrease as a result of the pandemic , which impact we operate result for fiscal 2020 .
# --------------------------------
# the test compare the fair value of each report unit to the carry value of that report unit .
# --------------------------------
# for overall industrial end - market , the manufacturing purchasing manager ' index ( " pmi " ) remain above 50 in North America as of December 31 , 2019 , whereas pmi in China have fluctuated around 50 throughout 2019 .
# --------------------------------
# in December 2019 , a outbreak of covid - 19 originate in wuhan , China , and in March 2020 , the World Health Organization characterize covid - 19 as a pandemic .
# --------------------------------
# on March 11 , 2020 , the World Health Organization characterize covid -19 as a pandemic .
# --------------------------------
# Lower sale in the U.K. and Australia be partially offset by increase sale in North America .
# --------------------------------
# in March 2020 , covid - 19 be categorized as a pandemic by the World Health Organization .
# --------------------------------
# in March 2020 , the who recognize covid - 19 as a pandemic .
# --------------------------------
# in early 2020 , the World Health Organization declare the coronavirus outbreak as a pandemic .
# --------------------------------
# the covid - 19 global pandemic present unprecedented challenge during fiscal 2021 .
# --------------------------------
# cantel Medical Corp. 2020 annual report on form 10 - k response thereto .
# --------------------------------
#
# Cluster 7:
# ----------------------------
# the slowdown be magnified by the negative economic impact of the covid - 19 pandemic .
# --------------------------------
# as a result of the covid - 19 pandemic , during the fourth quarter , the company evaluate the Wave report unit and
# --------------------------------
# on March 11 , 2020 , the World Health Organization declare a pandemic related to the rapidly spread coronavirus ( covid - 19 ) outbreak , which have lead to a global health emergency .
# --------------------------------
# however , the extent of this negative impact cannot be reasonably estimate at this time .
# --------------------------------
# in March 2020 , the World Health Organization declare the novel strain of coronavirus , covid - 19 , a global pandemic and recommend containment and mitigation measure worldwide .
# --------------------------------
# in March 2020 , the World Health Organization declare the novel strain of coronavirus , covid - 19 , a global pandemic and recommend containment and mitigation measure worldwide .
# --------------------------------
# the continue impact of this pandemic be not knowable at this time .
# --------------------------------
# in March 2020 , the World Health Organization announce that covid - 19 be a global pandemic .
# --------------------------------
# the outbreak of the covid - 19 pandemic present various global risk .
# --------------------------------
# the outbreak of the covid - 19 pandemic present various global risk .
# --------------------------------
# the recent novel coronavirus ( '' covid - 19 '' ) pandemic could materially adversely affect we financial condition and result of operation .
# --------------------------------
# in March 2020 , the World Health Organization characterize the outbreak of covid - 19 as a pandemic , and the President of the United State declare covid - 19 a national emergency .
# --------------------------------
# in March 2020 , the World Health Organization characterize the outbreak of covid - 19 as a pandemic , and the President of the United State declare the covid - 19 pandemic a national emergency .
# --------------------------------
# during March 2020 , the World Health Organization declare the covid - 19 outbreak to be a global pandemic .
# --------------------------------
# •natural disaster or public health emergency , such as the current covid - 19 pandemic ;
# --------------------------------
# forward - look statement inherently involve risk and uncertainties that could cause actual result to differ materially from the forward - look statement .
# --------------------------------
# the statement regard the current global covid - 19 pandemic .
# --------------------------------
# ( c ) represents severance charge related to the impact of covid - 19 pandemic .
# --------------------------------
# in March 2020 , the World Health Organization declare a novel strain of coronavirus , covid - 19 , a global pandemic .
# --------------------------------
# the outbreak of the novel coronavirus ( covid - 19 ) have evolve into a global pandemic .
# --------------------------------

# %% [markdown]
# # GMM

# %%
from sklearn import mixture

def group_sentence_by_GMM(lemma_sentences, data, num_clusters=8, repeats=5):
    
    gmm = mixture.GaussianMixture(num_clusters,
                              covariance_type="spherical", random_state=42)

    # samples are assigned to cluster labels 
    # starting from 0
    clusters = gmm.fit_predict(data)
    
    results = {i: [] for i in set(clusters)}
    
    for idx, c in enumerate(clusters):
        results[c].append(idx)
    
    return gmm, results



def distance(p1, p2):
    return cosine_distance(p1, p2)

def top_sentences_centroid(centroids, groups, data, lemma_sentences, topn=20):
    top_sentences = []
    
    for cid, idxs in groups.items():
        pair_dists = []
        
        for idx in idxs:
            pair_dists.append(distance(centroids[cid], data[idx]))

        print(f"Cluster {cid}:")
        print("----------------------------")
        
        for i in np.array(pair_dists).argsort()[-topn:]:
            print(" ".join(lemma_sentences[idxs[i]]))
            print("--------------------------------")
        print()

# %%
clusterer, groups = group_sentence_by_GMM(lemma_sentences, data)
top_sentences_centroid(clusterer.means_, groups, data, lemma_sentences)
# Out:
# Cluster 0:
# ----------------------------
# this may adversely affect we result of operation , financial position and cash flow .
# --------------------------------
# we expect to continue to see reduce demand in we non-cargo commercial business .
# --------------------------------
# we also maintain a inventory of certain product that we anticipate will be in great demand .
# --------------------------------
# we ability to consistently generate cash flow from operate activity be one of we most significant financial strength .
# --------------------------------
# if the company do not effectively respond to the demand of its customer , they could decrease they purchase from the company , cause the company 's net sale and net earnings to decline .
# --------------------------------
# unfavorable global or regional economic condition could adversely affect we business and financial result .
# --------------------------------
# the company have observe a decline in customer demand for its service and expect this decline to continue .
# --------------------------------
# we depend on we supplier for most of we product component and material .
# --------------------------------
# we expect to have continue access to capital market and to continue to return value to shareholders .
# --------------------------------
# there may also be continue pressure on we margin due to manufacturing variances result from low demand for certain of we product .
# --------------------------------
# the postponement of elective surgeries have negatively impact the demand for and sale of we product .
# --------------------------------
# while manufacturing operation be curtailed , we reduce we manufacturing cost .
# --------------------------------
# illness , travel restriction , absenteeism , or other workforce disruptions could negatively affect we supply chain , manufacturing , distribution , or other business process .
# --------------------------------
# we primary source of liquidity have be cash flow from operate activity .
# --------------------------------
# we cash balance and cash flow from operation be we primary source of liquidity and be generally sufficient to meet we liquidity need .
# --------------------------------
# in addition , we source raw material and certain component from Chinese supplier for use in we operation .
# --------------------------------
# we cannot guarantee that we will be able to increase manufacturing capacity to meet high product demand , which could prevent we from meeting increase customer demand .
# --------------------------------
# we have experience and expect to continue to experience unpredictable reduction in the demand for we product primarily due to we customer close they store .
# --------------------------------
# we have experience significant demand reduction and volatility for we product .
# --------------------------------
# we product use material and ingredient that we purchase from supplier .
# --------------------------------
#
# Cluster 1:
# ----------------------------
# with the recent outbreak of the coronavirus ( covid - 19 ) which have be declare by the World Health Organization to be a pandemic , management have evaluate the company 's accounting estimate that require consideration of forecasted financial information , include its allowances for doubtful account and inventory obsolescence , as well as the carry value of goodwill , intangible asset and other long - live asset .
# --------------------------------
# for detail on the effect of change in the value of we benefit plan obligation and asset on we financial result , see note 9 to the consolidated Financial statements in '' item 8 .
# --------------------------------
# at this time , we do not expect this disruption to have a significant impact on we full year 2020 unit case volume or financial result .
# --------------------------------
# during the fourth quarter of fiscal 2020 , there be no change in the internal control over financial report that materially affect , or be reasonably likely to materially affect , applied 's internal control over financial report .
# --------------------------------
# thecovid -19 pandemic have significantly impact ourfinancial position , result of operation , cash flow and liquidity as the spread of the pandemic and result governmental action have decrease the demand for we product , most notably throughout we dsd network , which have have a material impact on we revenue during the second half of we fiscal year end
# --------------------------------
# the company be dependent on its workforce to deliver its product primarily to the U.S. government .
# --------------------------------
# as such , it be possible that a shutdown of the U.S. government may occur , or interim budget may be adopt .
# --------------------------------
# from time to time , various disease such as the avian flu and the wuhan coronavirus , have spread across the world .
# --------------------------------
# Labor cost have also increase more than expect as a result of the tight labor market .
# --------------------------------
# there be no certainty that such measure will be sufficient to mitigate the risk pose by the virus , and we ability to perform critical function could be harmed .
# --------------------------------
# pandemics , such as the current global covid - 19 virus , outbreak of communicable infection or disease , or other public health concern in the market in which we consumer or employee live and / or in which we or we distributors , retailer , and supplier operate
# --------------------------------
# however , the increase consumer demand may reverse in the come month as consumer purchase behavior change as a result of the economic downturn .
# --------------------------------
# this statement be not a guarantee of future performance and involve a number of risk , uncertainties and assumption that be difficult to predict .
# --------------------------------
# the '' shelter in place '' and '' social distancing '' mandates have have and may continue to negatively affect demand by limiting the ability of we sale force to maintain they contact with health care personnel for a unknown period of time .
# --------------------------------
# accordingly , we management team may have to enact further precautionary measure to minimize any impact to we employee .
# --------------------------------
# in the event that access to ppe be constrain , sale may continue to be impact .
# --------------------------------
# • the pace at which hospital and clinical laboratories fully resume patient care that be not related to the covid - 19 pandemic ;
# --------------------------------
# the impact on we unfilled wholesale order position be unknown at this time .
# --------------------------------
# the impact on we unfilled wholesale order position be unknown at this time .
# --------------------------------
# the risk and uncertainties describe below be that that we have identify as material but be not the only risk and uncertainties that we face .
# --------------------------------
#
# Cluster 2:
# ----------------------------
# due to covid 19 restriction , the Court continue the hearing on the nine motion until July 16 , 2020 .
# --------------------------------
# overall demand for we product have decrease as a result of the pandemic , which impact we operate result for fiscal 2020 .
# --------------------------------
# in the United State , the U.S. government enact the cares Act on March 27 , 2020 .
# --------------------------------
# Potential impairment be identify by compare the fair value of a report unit to its carry value , include goodwill .
# --------------------------------
# as a result of this impairment analysis , no impairment be identify .
# --------------------------------
# certain provision of the cares Act impact the current fiscal year 2020 .
# --------------------------------
# certain provision of the cares Act impact the current fiscal year 2020 .
# --------------------------------
# the fair value of the report unit be determine use a estimate of future cash flow of the report unit and a risk- adjust discount rate to compute a net present value of future cash flow .
# --------------------------------
# ( a) includes a estimate negative impact of $ 0.60 - $ 0.65 from covid -19 .
# --------------------------------
# you should not rely on we result for any quarter or year as a indication of we future performance .
# --------------------------------
# the latter half of the fiscal year be negatively impact by the covid - 19 pandemic as net sale decrease by approximately 75 % during the third quarter of fiscal 2020 .
# --------------------------------
# the test compare the fair value of each report unit to the carry value of that report unit .
# --------------------------------
# accordingly , we expect we result of operation will be adversely affect for we fiscal year end June 30 , 2021 .
# --------------------------------
# the outbreak be subsequently declare a pandemic by the World Health Organization in March 2020 .
# --------------------------------
# we expect this trend to continue for at least a portion of fiscal 2021 , which will continue to negatively impact we net sale to customer in we foodservice segment .
# --------------------------------
# the revenue decreases in the consumer end market result from a broad - base decrease in demand for we product in this end market , include low demand for product use in portable consumer application .
# --------------------------------
# Lower sale in the U.K. and Australia be partially offset by increase sale in North America .
# --------------------------------
# Russia 's underlying net sale growth be drive by high volume of jdtw support by strong consumer demand .
# --------------------------------
# the pharmaceutical system unit 's revenue in 2020 reflect continue strength in demand for prefillable product .
# --------------------------------
# we international sale be primarily through we direct sale force .
# --------------------------------
#
# Cluster 3:
# ----------------------------
# the occurrence of one or more natural disaster , such as fire , hurricane , tornados , tsunamis , flood and earthquake ; geo-political event , such as civil unrest in a country in which we supplier or manufacturer be locate , or act of war or terrorism ( wherever locate around the world ) or military activity disrupt transportation , communication or utility system or otherwise cause damage to we business , employee , supplier , manufacturer and customer ; or other highly disruptive event , such as nuclear accident , pandemics , unusual weather condition or cyber attack , could have a material adverse effect on we business , financial condition and result of operation .
# --------------------------------
# we produce product through a combination of own facility and contract manufacturer .
# --------------------------------
# some of we product be manufacture at a single manufacturing facility or store at a single storage site .
# --------------------------------
# if we experience supply disruptions , we may not be able to develop alternate sourcing quickly .
# --------------------------------
# demand for we product could be significantly diminish by disrupt technology or product that replace they or render they obsolete .
# --------------------------------
# therefore , as a company engage in manufacturing , distribution and research and development on a global scale , we be subject to the risk inherent in such activity , include industrial accident , environmental event , fire , strike and other labor or industrial dispute , disruptions in logistics or information system ( such as we erp system ) , loss or impairment of key manufacturing or distribution site , product quality control issue , safety concern , licensing requirement and other regulatory or government issue , as well as natural disaster , pandemics , border dispute , act of terrorism and other external factor over which we have no control .
# --------------------------------
# this training program relate to , among other thing , ethics , compliance and product safety and quality , as well as sustainability goal .
# --------------------------------
# suppliers may choose to unilaterally withhold product , component or service .
# --------------------------------
# declines in automotive production also adversely impact volume in we specialty carbons product line .
# --------------------------------
# we business operation could suffer significant loss from natural disaster , pandemics , catastrophes , fire or other unexpected event .
# --------------------------------
# this cost increase may not be fully recoverable or adequately cover by insurance .
# --------------------------------
# in response to increase demand for we retail product during the second half of 2020 , we have take step , include modify production schedule and temporarily adjust product mix , to increase we production capacity to meet the increase demand for we retail product .
# --------------------------------
# • we have experience large fluctuations in the demand for we product , include a significant decrease in overall demand in the initial stage of the pandemic follow more recently by substantial increase in demand for certain of we product .
# --------------------------------
# Business and / or supply chain disruptions , plant and / or power outages and information technology system and / or network disruptions , regardless of cause include act of sabotage , employee error or other action , geo-political activity , local epidemics or pandemics , weather event and natural disaster could seriously harm Corteva 's operation as well as the operation of its customer and supplier .
# --------------------------------
# we may not be able to provide contract manufacturer with product volume that be high enough to achieve sufficient cost savings .
# --------------------------------
# increase regulation place restriction on the purchase or consumption of beverage alcohol product or increase price due to the imposition of duty or excise tax or change to international trade agreement or tariffs ; war , health epidemics or pandemics , quarantines , weather , and natural or man-made disaster .
# --------------------------------
# it be not know for how long they will remain close .
# --------------------------------
# we supply chain for non-nutritive sweeteners and certain other ingredient for we product include supplier in China .
# --------------------------------
# we believe we have sufficient liquidity available from operate cash flow , cash on hand , and availability under we $ 2.0 billionrevolving credit facility .
# --------------------------------
# we also manufacture and assemble product and perform various service at we manufacturing facility .
# --------------------------------
#
# Cluster 4:
# ----------------------------
# the second half of the fiscal year end July , 31 , 2020 be impact by the coronavirus ( covid - 19 ) pandemic , result in atypical seasonality .
# --------------------------------
# Cash flow provide by financing activity for fiscal 2020 be primarily attribute to the net fund receive from nine ( 9 ) unsecured promissory note payable under cares Act payroll Protection Program ( '' ppp '' ) total $ 19,927 in order to provide need relief for allowable expense under the cares Act ppp .
# --------------------------------
# see '' liquidity and Capital resources '' below for detail .
# --------------------------------
# Act on we condense consolidated statement of operation and we condense consolidated statement of cash flow .
# --------------------------------
# cantel Medical Corp. 2020 annual report on form 10 - k response thereto .
# --------------------------------
# there be a risk this may not always be the case .
# --------------------------------
# word such as '' could , '' '' will , '' '' may , '' '' expect , '' '' anticipate , '' '' target , '' '' goal , '' '' project , '' '' intend , '' '' plan , '' '' believe , '' '' seek , '' '' estimate , '' '' predicts '' and variations on such word , and similar expression that reflect we current view with respect to future event and operational and financial performance , be intend to identify such forward - look statement .
# --------------------------------
# when use in this annual report , word such as '' anticipate , '' '' believe , '' '' contemplates , '' '' estimate , '' '' expect , '' '' plan , '' '' project '' and similar expression be intend to identify forward - look statement .
# --------------------------------
# the follow promissory note be execute by the company and its subsidiaries : gee Group , Inc. , for $ 1992 ( the '' gee Group note '' ) , scribe solution , Inc. for $ 277 ( the '' scribe note '' ) , agile resources , Inc. be for $ 1206 ( the '' agile note '' ) , access data consulting Corporation for $ 1456 ( the '' access note '' ) , paladin consulting , Inc. for $ 1,925 ( the '' paladin note '' ) , sni company , Inc. for $ 10000 ( the '' sni note '' ) , triad personnel service , Inc. for $ 404 ( the '' triad personnel note '' ) , triad logistics , Inc. for $ 78 ( the '' triad logistics note '' ) , and bmch , Inc. for $ 2589 ( the '' bmch note '' ) .
# --------------------------------
# you can identify forward - look statement by terminology such as '' may , '' '' should , '' '' expect , '' '' plan , '' '' anticipate , '' '' believe , '' '' estimate , '' '' predicts , '' '' potential , '' '' continue , '' or the negative of this term or other comparable terminology .
# --------------------------------
# forward - look statement may contain word such as '' may , '' '' will , '' '' should , '' '' could , '' '' would , '' '' expect , '' '' plan , '' '' anticipate , '' '' believe , '' '' estimate , '' '' intend , '' '' potential '' and '' continue , '' the negative of this term , or other comparable terminology .
# --------------------------------
# local political and economic condition ; natural disaster , health epidemics and geopolitical instability ;
# --------------------------------
# without limiting the foregoing , word or phrase such as '' expect , '' '' anticipate , '' '' goal , '' '' project , '' '' intend , '' '' plan , '' '' believe , '' '' seek , '' '' may , '' '' could , '' '' aspire '' and variations of such word and similar expression generally identify forward - look statement .
# --------------------------------
# •terrorist activity , natural disaster , pandemics and other catastrophic event ;
# --------------------------------
# forward - look statement include all statement that be not historical fact and can be identify by term such as '' anticipate , '' '' believe , '' '' could , '' '' estimate , '' '' expect , '' '' hope , '' '' intend , '' '' may , '' '' plan , '' '' potential , '' '' predicts , '' '' project , '' '' should , '' '' will , '' '' would '' or similar expression .
# --------------------------------
# word such as '' expect , '' '' anticipate , '' '' target , '' '' goal , '' '' project , '' '' intend , '' '' plan , '' '' believe , '' '' seek , '' '' estimate , '' '' continue , '' '' may , '' '' could '' and '' will , '' and variations of such word and similar expression be intend to identify such forward - look statement .
# --------------------------------
# the term '' may , '' '' should , '' '' could , '' '' anticipate , '' '' believe , '' '' estimate , '' '' expect , '' '' objective , '' '' plan , '' '' project '' and similar expression be intend to identify forward - look statement .
# --------------------------------
# you can identify this forward - look statement through the use of word such as '' may , '' '' will , '' '' can , '' '' anticipate , '' '' assume , '' '' should , '' '' indicate , '' '' would , '' '' believe , '' '' contemplate , '' '' expect , '' '' seek , '' '' estimate , '' '' continue , '' '' plan , '' '' project , '' '' predict , '' '' could , '' '' intend , '' '' target , '' '' potential , '' and other similar word and expression of the future .
# --------------------------------
# some of the forward - look statement can be identify by word like '' anticipate , '' '' believe , '' '' expect , '' '' may , '' '' will , '' '' can , '' '' could , '' '' should , '' '' intend , '' '' project , '' '' predict , '' '' plan , '' '' estimate , '' '' goal , '' '' target , '' '' possible , '' '' potential , '' '' would , '' '' seek , '' and similar reference to future period .
# --------------------------------
# the discount cash flow technique require the use of cash flow forecast .
# --------------------------------
#
# Cluster 5:
# ----------------------------
# during fiscal 2020 , 2019 and 2018 , net cash use in investing activity include capital expenditure of $ 33796 , $ 95,438 and $ 37698 , respectively , which include expenditure for erp software , building improvement and purchase of manufacturing and computer equipment .
# --------------------------------
# the decline be partially offset by a increase in we ready to assemble furniture sell through e-commerce , which grow 35.7 % year over year , primarily drive by increase demand .
# --------------------------------
# Gross profit in fiscal2020decreased $ 41.0 million , or22.9 % , to $ 138.1 millionfrom $ 179.1 millionin fiscal 2019 .
# --------------------------------
# Lower fix cost ( $ 30 million ) be drive by low production volume and other cost reduction action .
# --------------------------------
# Net sale for fiscal 2020 decrease compare to fiscal 2019 primarily due to low customer investment in display manufacturing equipment for tvs , partially offset by high customer investment in display manufacturing equipment for mobile product .
# --------------------------------
# at September 25 , 2020 , approximately $ 75000 be available under we amended credit agreement .
# --------------------------------
# Capital expenditure be $ 299 million in 2020 , $ 384 million in 2019 and $ 407 million in 2018 .
# --------------------------------
# prior year free cash flow result include the impact of the acquisition of lpw technology Ltd. , for a cash purchase price of $ 79.0 million .
# --------------------------------
# fiscal 2020 operate profitdecreased $ 35 million ( 35 % ) from the prior year .
# --------------------------------
# in addition , we perform impairment test on the long - live asset allocate to the asset group of the ils report unit , include intangible asset , property , plant and equipment and right - of - use ( " rou " ) asset as of April 4 , 2020 and record non-cash pre-tax charge , in the quarter end April 4 , 2020 , related to the impairment intangible asset , property , plant and equipment and rou asset of the ils report unit of $ 33.9 million , $ 85.6 million and $ 1.8 million , respectively .
# --------------------------------
# the result reflect high demand and good mix during the first half of fiscal year 2020 .
# --------------------------------
# • diluted eps of $ 8.55 increase 8 % , or $ 0.61 , and adjust diluted eps of $ 8.38 increase 2 % , or $ 0.17 .
# --------------------------------
# Canada 's underlying net sale be flat as favorable price / mix be offset by low volume .
# --------------------------------
# overall , underlying sale decrease 7 percent in the America ( U.S. down 8 percent ) and 3 percent in Europe , while Asia , Middle East & Africa decrease 11 percent ( China down 11 percent ) .
# --------------------------------
# fiscal 2020 it&s segment net salesdecreased by $ 155 million ( 25 % ) from fiscal 2019 to $ 455 million .
# --------------------------------
# operate cash flow be expect to be approximately $ 3.1 billion and free cash flow , which excludes target capital spend of $ 600 million , be expect to be approximately $ 2.5 billion .
# --------------------------------
# no borrowing have be make on the $ 25.0 million credit facility .
# --------------------------------
# the divestiture of two small non- core business subtracted 1 percent ( $ 42 ) and foreign currency translation deduct 1 percent ( $ 30 ) .
# --------------------------------
# we also generate $ 52.8 million of cash flow from operation .
# --------------------------------
# cantel Medical Corp. 2020 annual report on form 10 - k the second quarter of fiscal 2019 .
# --------------------------------
#
# Cluster 6:
# ----------------------------
# the outbreak of the covid - 19 pandemic present various global risk .
# --------------------------------
# on March 11 , 2020 , the World Health Organization declare a pandemic related to the rapidly spread coronavirus ( covid - 19 ) outbreak , which have lead to a global health emergency .
# --------------------------------
# in March 2020 , the World Health Organization announce that covid - 19 be a global pandemic .
# --------------------------------
# the recent novel coronavirus ( '' covid - 19 '' ) pandemic could materially adversely affect we financial condition and result of operation .
# --------------------------------
# during and subsequent to the fourth quarter of fiscal 2020 , the company have be impact by the spread of covid - 19 .
# --------------------------------
# the continue impact of this pandemic be not knowable at this time .
# --------------------------------
# in March 2020 , the World Health Organization characterize the outbreak of covid - 19 as a pandemic , and the President of the United State declare the covid - 19 pandemic a national emergency .
# --------------------------------
# in March 2020 , the World Health Organization characterize the outbreak of covid - 19 as a pandemic , and the President of the United State declare covid - 19 a national emergency .
# --------------------------------
# the coronavirus pandemic and associate containment effort adversely affect we business , result of operation and cash flow during fiscal 2020 .
# --------------------------------
# the statement regard the current global covid - 19 pandemic .
# --------------------------------
# in December 2019 , a outbreak of covid - 19 originate in wuhan , China , and in March 2020 , the World Health Organization characterize covid - 19 as a pandemic .
# --------------------------------
# tough comparison to the fourth quarter of fiscal 2019 along with the adverse effect of covid - 19 negatively impact full - year growth .
# --------------------------------
# during March 2020 , the World Health Organization declare the covid - 19 outbreak to be a global pandemic .
# --------------------------------
# ( c ) represents severance charge related to the impact of covid - 19 pandemic .
# --------------------------------
# in March 2020 , the who recognize covid - 19 as a pandemic .
# --------------------------------
# the outbreak of the novel coronavirus ( covid - 19 ) have evolve into a global pandemic .
# --------------------------------
# the impact of the covid - 19 pandemic on dsd revenue be during the second half of we fiscal year end
# --------------------------------
# in March 2020 , covid - 19 be categorized as a pandemic by the World Health Organization .
# --------------------------------
# the covid - 19 global pandemic present unprecedented challenge during fiscal 2021 .
# --------------------------------
# additionally , because of the covid - 19 pandemic during the second half of the company 's fiscal year end
# --------------------------------
#
# Cluster 7:
# ----------------------------
# substantially all order be expect to be fill within twelve month .
# --------------------------------
# the decrease in total segment ebit be drive by low volume in reinforcement materials and purification solution and low margin in performance Chemicals , partially offset by low fix cost .
# --------------------------------
# almost all location be currently require to operate at only 50 % capacity .
# --------------------------------
# we principal use of cash in we operate activity be for purchase and carry inventories and carry seasonal account receivable .
# --------------------------------
# Act include the deferral of certain payroll tax , relief for retaining employee , and other provision .
# --------------------------------
# Act include the deferral of certain payroll tax , relief for retaining employee , and other provision .
# --------------------------------
# we cash and cash equivalent be hold in a mix of money market fund , bank demand deposit account and foreign bank account .
# --------------------------------
# the market multiples valuation technique include significant judgment in the determination of the market multiples .
# --------------------------------
# we free cash flow , which we define under '' non-gaap Financial measures '' below , be positive $ 21.8 millionas compare to negative $ 53.7 millionfor the same period a year ago .
# --------------------------------
# for overall industrial end - market , the manufacturing purchasing manager ' index ( " pmi " ) remain above 50 in North America as of December 31 , 2019 , whereas pmi in China have fluctuated around 50 throughout 2019 .
# --------------------------------
# Lower unit margin be due to a more competitive pricing environment and weak product mix in the fumed metal oxides product line and weak product mix in we specialty carbons product line due to low demand in automotive application .
# --------------------------------
# the industry remain vulnerable to exogenous development include fuel price spike , credit market shocks , act of terrorism , natural disaster , conflict , epidemics and increase global environmental regulation .
# --------------------------------
# we extend a 25 % salary reduction for we ceo and cfo / coo and 50 % cash compensation reduction for we board of director through October 1 , 2020 .
# --------------------------------
# Blue Force tracking ( '' bft - 1 '' ) program ; and ( v) $ 6.3 million of initial funding on a $ 12.6 million contract from a major U.S. subcontractor for the supply of high reliability eee space component to be utilized on NASA 's artemis mission .
# --------------------------------
# on March 17 , 2020 , the bee Street tender offer expired .
# --------------------------------
# we be award a number of important order include : ( I ) contract value at more than $ 2.2 million for ka-band high - power travel wave tube amplifiers ( '' twtas '' ) for trailer - base satellite communication terminals ; ( ii ) a contract value at more than $ 1.5 million for 500w ka-band twtas for a track , telemetry and command application to be deploy globally by a major satellite service provider ; ( iii ) $ 1.3 million in order for advanced satellite modems , wan optimization and redundancy switch to support cellular lte backhaul for a service provider in the Middle East ; and ( iv ) a $ 1.1 million order for satellite ground station equipment from a South East Asia Ministry of Defense for a network upgrade , which could expand to more than 2000 unit .
# --------------------------------
# excluding surcharge revenue , salesdecreased 14 percent on20 percentlowershipment volume .
# --------------------------------
# operate expensesincreased as we peo service zero-margin benefit pass-throughcosts increase to $ 2907.
# --------------------------------
# we dsd customer consist of small independent restaurant , foodservice operator , large institutional buyer , and convenience store chain , hotel , casinos , healthcare facility , and foodservice distributors .
# --------------------------------
# Goodwill be require to be test for impairment at least annually .
# --------------------------------

# %% [markdown]
# # LDA

# %%
sentences = []
for s in lemma_sentences:
    sentences.append(" ".join(s))

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

def group_sentence_by_lda(sentences, num_clusters=8):
    tf_vectorizer = CountVectorizer(min_df=5, stop_words = "english")
    tf = tf_vectorizer.fit_transform(sentences)
    
    tf_feature_names = tf_vectorizer.get_feature_names()
    
    lda = LatentDirichletAllocation(num_clusters, max_iter=30, verbose=1, evaluate_every=1, n_jobs=1, random_state=0)
    
    doc_distribution = lda.fit_transform(tf)
    clusters = doc_distribution.argsort()[:, -1]
    
    results = {i: [] for i in set(clusters)}
    
    for idx, c in enumerate(clusters):
        results[c].append((idx, doc_distribution[idx][c]))
    

    return results

def print_cluster_topn(results, sentences, cluster_number, topn=20):
    topn_sentences = sorted(results[cluster_number], key=lambda x: -x[1])[:topn]
    print(f"Cluster {cluster_number}:\n-------------")
    for idx, score in topn_sentences:
        print(idx, sentences[idx])
        print("---------------------")

# %%
results = group_sentence_by_lda(sentences)
# Out:
# iteration: 1 of max_iter: 30, perplexity: 1069.9717
# iteration: 2 of max_iter: 30, perplexity: 905.9398
# iteration: 3 of max_iter: 30, perplexity: 829.8457
# iteration: 4 of max_iter: 30, perplexity: 788.7253
# iteration: 5 of max_iter: 30, perplexity: 763.9482
# iteration: 6 of max_iter: 30, perplexity: 749.5778
# iteration: 7 of max_iter: 30, perplexity: 740.7231
# iteration: 8 of max_iter: 30, perplexity: 734.7749
# iteration: 9 of max_iter: 30, perplexity: 730.4759
# iteration: 10 of max_iter: 30, perplexity: 727.3043
# iteration: 11 of max_iter: 30, perplexity: 724.8657
# iteration: 12 of max_iter: 30, perplexity: 722.9127
# iteration: 13 of max_iter: 30, perplexity: 721.3494
# iteration: 14 of max_iter: 30, perplexity: 719.9954
# iteration: 15 of max_iter: 30, perplexity: 718.7817
# iteration: 16 of max_iter: 30, perplexity: 717.6996
# iteration: 17 of max_iter: 30, perplexity: 716.8086
# iteration: 18 of max_iter: 30, perplexity: 716.0449
# iteration: 19 of max_iter: 30, perplexity: 715.4217
# iteration: 20 of max_iter: 30, perplexity: 714.8635
# iteration: 21 of max_iter: 30, perplexity: 714.3967
# iteration: 22 of max_iter: 30, perplexity: 713.9918
# iteration: 23 of max_iter: 30, perplexity: 713.6859
# iteration: 24 of max_iter: 30, perplexity: 713.4105
# iteration: 25 of max_iter: 30, perplexity: 713.1565
# iteration: 26 of max_iter: 30, perplexity: 712.9637
# iteration: 27 of max_iter: 30, perplexity: 712.8343
# iteration: 28 of max_iter: 30, perplexity: 712.6956
# iteration: 29 of max_iter: 30, perplexity: 712.5825
# iteration: 30 of max_iter: 30, perplexity: 712.4971

# %%
print_cluster_topn(results, sentences, 0, 20)
# Out:
# Cluster 0:
# -------------
# 24575 the $ 28.6 million , or 8.8 % , increase in net sale in 2020 as compare to 2019 be mainly due to a $ 27.6 million increase in net sale from Globe ( acquire in July 2019 ) , a $ 13.5 million increase in net sale at vacco due to high shipments of space product , partially offset by a $ 6.1 million decrease in net sale at mayday , a $ 3.7 million decrease in net sale at crissair and a $ 3.0 million decrease in net sale at pti all drive by the covid - 19 pandemic in the current year .
# ---------------------
# 4818 the decrease in the fsg 's operate income as a percentage of net sale reflect the previously mention low gross profit margin and a .5 % increase in sg&a expense as a percentage of net sale mainly from the previously mention high bad debt expense and fix cost efficiencies lose result from the pandemic 's impact , partially offset by the previously mention low performance - base compensation expense .
# ---------------------
# 68319 although we experience growth in the automotive market in the first nine month of fiscal year 2020 when compare to the nine - month period of the prior fiscal year , lead by the continue ramp - up of new program include program for fully electric vehicle , we experience a 43 % decline in sale in the automotive market in the last quarter of fiscal year 2020 when compare to the fourth quarter of the prior fiscal year due to the impact of covid - 19 .
# ---------------------
# 71654 within the mastercraft segment , the decrease for the mastercraft brand be also partially offset by aviara sale in fiscal 2020 ; a $ 23.1 million decrease for the nauticstar segment primarily as a result of we temporary manufacturing suspension , we pre- covid - 19 pandemic effort to allow we dealer to right - size pipeline inventory level , and softness in the overall saltwater category during the first half of fiscal 2020 , partially offset by high price ;
# ---------------------
# 708 operate profit be $ 24 million low in fiscal 2020 as compare to fiscal 2019 as a result of the $ 76 million decrease in gross profit drive by the decline in net sale volume , offset by cost reduction action to reduce sell , administrative , and engineering expense ( " sae " ) , and impairment & divestiture benefit in the current year as oppose to charge in the prior year .
# ---------------------
# 13646 the decrease in hpp product revenue of $ 3.0 million in the fiscal year end September 30 , 2020 be primarily the result of a approximately $ 1.8 million decrease in myricom product line shipments combine with a $ 1.2 million decrease in multicomputer product line shipments for the fiscal year end September 30 , 2020 as compare to the fiscal year end September 30 , 2019 .
# ---------------------
# 2791 we annualized fourth quarter inventory turn for fiscal 2020 decrease to 1.9 turn from 2.1 turn in fiscal 2019 due to slow consumption of inventory result from a shift in demand partially related to the covid - 19 pandemic and low intangibles amortization in cost of goods sell as a result of the impairment charge record in the second quarter of fiscal 2020 .
# ---------------------
# 4364 consolidated net revenue for the fiscal quarter end March 31 , 2020 of $ 34681 decrease by approximately $ 1496 , or 4 % , as compare with consolidated net revenue for the fiscal quarter end March 31 , 2019 of $ 36,177 , and decrease by approximately $ 2876 , or 8 % , as compare with consolidated net revenue for the sequential fiscal quarter end December 31 , 2019 of $ 37,557 .
# ---------------------
# 11751 excluding the impact of impairment and restructuring activity , operate income be down $ 26.4 million in fiscal 2020 compare to fiscal 2019 due to low direct volume and low direct average sell price in steel processing , partially offset by low sell , general and administrative ( '' sg&a '' ) expense and low overall corporate cost .
# ---------------------
# 11840 operate income for the year end September 30 , 2020 increase $ 9.8 million with a margin increase of 80 bps due to improve productivity , pricing and mix , retrospective tariff exclusions and reduce restructuring expense despite low sale volume plus high input cost drive by tariffs and we covid - 19 response .
# ---------------------
# 33487 income for the year end June 30 , 2020 , after depreciation expense of $ 0.2 million and other income of $ 0.2 million , result in approximately $ 0.4 million before income tax provision of approximately $ 28 thousand result in a net income of approximately $ 0.3 million as compare to a net loss of $ 13 thousand for the year end June 30 , 2019 .
# ---------------------
# 1247 selling and administrative expense as a percentage of revenue in 2019 be flat compare with 2018 as high revenue and the achievement of cost synergies offset the impact of high sell and general administrative cost attributable to bard , which have a high sell and administrative spend profile than BD , in we result for the first quarter of fiscal year 2019 , as note above .
# ---------------------
# 82115 Cost of sale for the year end September 30 , 2020 increase by $ 62.2 million , or 11.5 % , to $ 603.2 million from $ 541.0 million for the year end September 30 , 2019 primarily due to increase cost on high sale volume and the impact of covid - 19 related production cost partially offset by manufacturing productivity .
# ---------------------
# 11467 the roll twelve month shipments for 2020 and 2019 reflect a contraction in shipments as dealer rationalized inventory in the first six month of we fiscal year 2020 , follow by a continue reduction in dealer inventory in the back half of we fiscal year 2020 due to constrain production activity during the covid - 19 pandemic amidst a strong recovery in retail sale .
# ---------------------
# 71655 a $ 23.1 million decrease for the nauticstar segment primarily as a result of we temporary manufacturing suspension , we pre- covid - 19 pandemic effort to allow we dealer to right - size pipeline inventory level , and softness in the overall saltwater category during the first half of fiscal 2020 , partially offset by high price ; a net $ 14.9 million decrease as the crest acquisition in the second quarter of fiscal 2019 add net sale of $ 18.9 million for the first quarter of fiscal 2020 which be offset by a total $ 33.7 million period - over - period decrease attributable to the remain quarter in fiscal 2020 primarily as a result of we temporary manufacturing suspension and we pre- covid - 19 pandemic effort to allow we dealer to right - size pipeline inventory level , and high pre-pandemic retail rebate discount , partially offset by high price ;
# ---------------------
# 56689 we produce 117.8 million and 129.3 million gallons of ethanol for the fiscal year end September 30 , 2020 ( " fiscal 2020 " ) and September 30 , 2019 ( '' fiscal 2019 '' ) , respectively , and approximately 74.3 % and 75.4 % of we revenue be derive from the sale of ethanol in fiscal 2020 and fiscal 2019 , respectively .
# ---------------------
# 4496 organic net sale result in we convenience stores & foodservice , Europe & Australia , and Asia & Latin America segment be below fiscal 2019 level , due to a slow start to the year in each of that segment , as well as the pandemic-related headwinds impacting convenience stores & foodservice and Asia & Latin America in the second half of the year .
# ---------------------
# 11841 adjusted ebitda for the year end September 30 , 2020 increase $ 2.6 million with a increase in margin of 40 bps due to improve productivity , pricing and mix , retrospective tariff exclusions despite low sale volume plus high input cost drive by tariffs and we covid - 19 response .
# ---------------------
# 71652 a $ 65.4 million decrease for the mastercraft segment , primarily due to low wholesale unit volume for the mastercraft brand as a result of we temporary manufacturing suspension and we pre- covid - 19 pandemic effort to reduce dealer inventory level , partially offset by a richer mix of high - price and high - contented model and low dealer incentive .
# ---------------------
# 1943 in fiscal 2020 , ebit in performance Chemicals decrease $ 34 million compare to fiscal 2019 primarily due to low unit margin ( $ 21 million ) , the unfavorable impact of inventory comparison ( $ 11 million ) , and high fix cost ( $ 4 million ) , partially offset by high volume ( $ 4 million ) .
# ---------------------
